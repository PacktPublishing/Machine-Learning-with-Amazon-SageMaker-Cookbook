# %%
import boto3
import sagemaker

from sagemaker.session import Session
from sagemaker.feature_store.feature_group import FeatureGroup

# %%
region = boto3.Session().region_name
session = boto3.Session(region_name=region)

client = session.client(
    service_name='sagemaker', 
    region_name=region
)
runtime = session.client(
    service_name='sagemaker-featurestore-runtime', 
    region_name=region
)

feature_store_session = Session(
    boto_session=session,
    sagemaker_client=client,
    sagemaker_featurestore_runtime_client=runtime
)

# %%
# %store -r feature_group_name

feature_group = FeatureGroup(
    name=feature_group_name, 
    sagemaker_session=feature_store_session
)

# %%
feature_group.describe()
# Out:
# {'FeatureGroupArn': 'arn:aws:sagemaker:us-east-1:581320662326:feature-group/cookbook-feature-group',
#  'FeatureGroupName': 'cookbook-feature-group',
#  'RecordIdentifierFeatureName': 'index',
#  'EventTimeFeatureName': 'event_time',
#  'FeatureDefinitions': [{'FeatureName': 'approved', 'FeatureType': 'Integral'},
#   {'FeatureName': 'sex', 'FeatureType': 'Integral'},
#   {'FeatureName': 'math', 'FeatureType': 'Integral'},
#   {'FeatureName': 'science', 'FeatureType': 'Integral'},
#   {'FeatureName': 'technology', 'FeatureType': 'Integral'},
#   {'FeatureName': 'random1', 'FeatureType': 'Integral'},
#   {'FeatureName': 'random2', 'FeatureType': 'Integral'},
#   {'FeatureName': 'index', 'FeatureType': 'Integral'},
#   {'FeatureName': 'event_time', 'FeatureType': 'Fractional'}],
#  'CreationTime': datetime.datetime(2021, 6, 13, 17, 15, 42, 30000, tzinfo=tzlocal()),
#  'OnlineStoreConfig': {'EnableOnlineStore': True},
#  'OfflineStoreConfig': {'S3StorageConfig': {'S3Uri': 's3://sagemaker-cookbook-bucket/chapter07/input',
#    'ResolvedOutputS3Uri': 's3://sagemaker-cookbook-bucket/chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623604542/data'},
#   'DisableGlueTableCreation': False,
#   'DataCatalogConfig': {'TableName': 'cookbook-feature-group-1623604542',
#    'Catalog': 'AwsDataCatalog',
#    'Database': 'sagemaker_featurestore'}},
#  'RoleArn': 'arn:aws:iam::581320662326:role/SuperAdminRole',
#  'FeatureGroupStatus': 'Created',
#  'ResponseMetadata': {'RequestId': 'f78fc291-6c91-473e-96d5-5aa448ba779e',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'f78fc291-6c91-473e-96d5-5aa448ba779e',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '1614',
#    'date': 'Sun, 13 Jun 2021 17:18:18 GMT'},
#   'RetryAttempts': 0}}

# %%
table = feature_group.athena_query().table_name
table
# Out:
# 'cookbook-feature-group-1623604542'

# %%
describe_response = feature_group.describe()
offline_config = describe_response['OfflineStoreConfig']
s3_uri = offline_config['S3StorageConfig']['S3Uri']
s3_uri
# Out:
# 's3://sagemaker-cookbook-bucket/chapter07/input'

# %%
# !aws s3 ls {s3_uri} --recursive
# Out:
# 2021-05-24 13:19:31          0 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1621862289/cookbook-feature-group2021-05-24T13:18:09.536Z.txt
# 2021-05-24 13:24:04      39388 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1621862289/data/year=2021/month=05/day=24/hour=13/20210524T131737Z_e6ORP4xrgB871rdp.parquet
# 2021-05-24 13:24:04      36764 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1621862289/data/year=2021/month=05/day=24/hour=13/20210524T131737Z_iEvmDP797Fbl6RAm.parquet
# 2021-05-24 13:24:04      39184 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1621862289/data/year=2021/month=05/day=24/hour=13/20210524T131737Z_vYGXQWqeKRLH7OJb.parquet
# 2021-05-24 13:24:04      38418 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1621862289/data/year=2021/month=05/day=24/hour=13/20210524T131737Z_xfb8J2vUWHOA4pKz.parquet
# 2021-05-26 20:16:15          0 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1622060091/cookbook-feature-group2021-05-26T20:14:51.846Z.txt
# 2021-05-26 20:20:08      38469 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1622060091/data/year=2021/month=05/day=26/hour=20/20210526T200348Z_0DsmSLxIsJBe2iaH.parquet
# 2021-05-26 20:20:27      36797 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1622060091/data/year=2021/month=05/day=26/hour=20/20210526T200348Z_GqJXZqjs3SaUZkll.parquet
# 2021-05-26 20:20:27      39431 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1622060091/data/year=2021/month=05/day=26/hour=20/20210526T200348Z_QQgZCWZMEy00k6iB.parquet
# 2021-05-26 20:20:07      39207 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1622060091/data/year=2021/month=05/day=26/hour=20/20210526T200348Z_cI08NPIfqR4jZK9T.parquet
# 2021-05-26 20:21:49          0 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1622060427/cookbook-feature-group2021-05-26T20:20:27.173Z.txt
# 2021-05-26 20:26:37      38452 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1622060427/data/year=2021/month=05/day=26/hour=20/20210526T200348Z_436EcQIGr80f6npT.parquet
# 2021-05-26 20:26:27      36781 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1622060427/data/year=2021/month=05/day=26/hour=20/20210526T200348Z_5YI1sQyx76iyen41.parquet
# 2021-05-26 20:26:27      39181 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1622060427/data/year=2021/month=05/day=26/hour=20/20210526T200348Z_B5w609Dy9R3Ir8Ol.parquet
# 2021-05-26 20:26:37      39395 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1622060427/data/year=2021/month=05/day=26/hour=20/20210526T200348Z_yHnA6JEQiXtX2sah.parquet
# 2021-05-26 21:07:42          0 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1622063180/cookbook-feature-group2021-05-26T21:06:20.467Z.txt
# 2021-05-26 21:12:25      39192 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1622063180/data/year=2021/month=05/day=26/hour=21/20210526T210547Z_RX55BCuiXdgVutHd.parquet
# 2021-05-26 21:12:56      38449 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1622063180/data/year=2021/month=05/day=26/hour=21/20210526T210547Z_WXO9OjzYJ28cxgdS.parquet
# 2021-05-26 21:12:15      36788 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1622063180/data/year=2021/month=05/day=26/hour=21/20210526T210547Z_boMyGx2R2v3pINa1.parquet
# 2021-05-26 21:13:00      39399 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1622063180/data/year=2021/month=05/day=26/hour=21/20210526T210547Z_rwLEiycQCDBAmMqC.parquet
# 2021-05-29 14:13:19          0 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1622297517/cookbook-feature-group2021-05-29T14:11:57.610Z.txt
# 2021-05-29 14:18:15      38429 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1622297517/data/year=2021/month=05/day=29/hour=14/20210529T141125Z_6rLVAFsdbpzGPTVb.parquet
# 2021-05-29 14:18:15      36809 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1622297517/data/year=2021/month=05/day=29/hour=14/20210529T141125Z_86mmGh2e8330fxXX.parquet
# 2021-05-29 14:18:46      39197 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1622297517/data/year=2021/month=05/day=29/hour=14/20210529T141125Z_AzZbgG7Mv5DMLG3N.parquet
# 2021-05-29 14:18:05      39405 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1622297517/data/year=2021/month=05/day=29/hour=14/20210529T141125Z_MQsq0vZVZmEwQuBD.parquet
# 2021-06-13 16:41:39          0 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/cookbook-feature-group2021-06-13T16:40:09.828Z.txt
# 2021-06-13 16:46:56       3328 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_1Uba6kLoriqZyqRN.parquet
# 2021-06-13 16:46:56       3285 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_1tVxGDZ7zcHB14Oe.parquet
# 2021-06-13 16:46:55       3291 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_2jU2q0SGzNEYCfRL.parquet
# 2021-06-13 16:46:57       3676 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_4hN7E5blXWQn9Kbr.parquet
# 2021-06-13 16:46:55       3809 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_6cQrfAlZpOdWVmf1.parquet
# 2021-06-13 16:46:56       3126 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_8hnGztb8fElXohb4.parquet
# 2021-06-13 16:46:56       3479 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_8uk1hlnabiP2xcFQ.parquet
# 2021-06-13 16:46:26       3591 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_90I7RvIivsBfsaTz.parquet
# 2021-06-13 16:46:56       3405 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_9fi1bslp3R0k5lVZ.parquet
# 2021-06-13 16:46:56       3536 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_AHEuVFXgCyBMOP5f.parquet
# 2021-06-13 16:46:55       3312 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_Ae3wtd9Kvyz2Vi54.parquet
# 2021-06-13 16:46:56       3533 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_AwZ7zuQimw26Cb8P.parquet
# 2021-06-13 16:46:56       3453 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_Azw39PjHTVGR6E6h.parquet
# 2021-06-13 16:46:55       3595 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_Bu5whvB4TVbFsvEX.parquet
# 2021-06-13 16:46:56       3231 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_CJg7Nj4o6wMOiBeu.parquet
# 2021-06-13 16:46:56       3447 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_CcobWGM08xcEQy1p.parquet
# 2021-06-13 16:46:56       3643 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_CnWlRVpHClWiaupc.parquet
# 2021-06-13 16:46:56       3325 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_D2uGAViL1cgB4KHK.parquet
# 2021-06-13 16:46:57       3170 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_E9PXxH5aWqfUZCri.parquet
# 2021-06-13 16:46:56       3398 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_FLs8XmjJcPVHPsmE.parquet
# 2021-06-13 16:46:56       3181 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_H06c1ptLWqi0rbgw.parquet
# 2021-06-13 16:46:56       3487 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_HVcTJykott14e0jg.parquet
# 2021-06-13 16:46:56       3646 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_HujJEAhEqWNIbnT7.parquet
# 2021-06-13 16:46:56       3287 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_KKGAOa4sl2hVwmJX.parquet
# 2021-06-13 16:46:56       3520 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_MXe3dXdAO3wD8hHf.parquet
# 2021-06-13 16:46:56       3632 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_NEnbfA9HbDFnJCnF.parquet
# 2021-06-13 16:46:56       3118 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_Nz6BaQ9Ejyt7fNOQ.parquet
# 2021-06-13 16:46:56       3622 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_PuTJuyODWda0kX0x.parquet
# 2021-06-13 16:46:56       3438 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_QqBNOr3YZfZHCOLb.parquet
# 2021-06-13 16:46:26       3584 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_TEfc08alVmJYkflM.parquet
# 2021-06-13 16:46:26       3430 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_TjDBFScjujFtsa5l.parquet
# 2021-06-13 16:46:56       3596 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_U8wpCvuDWUxTTtE9.parquet
# 2021-06-13 16:46:56       3062 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_WrYYa7ZpsWhGbNyC.parquet
# 2021-06-13 16:46:26       3462 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_ZdsFJuHQxtLI0jYJ.parquet
# 2021-06-13 16:46:56       3565 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_bUJG4zDzgBvHyqk5.parquet
# 2021-06-13 16:46:56       3724 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_czfBgyzJey8uH3c4.parquet
# 2021-06-13 16:46:56       3431 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_euLjtiHjEoRiN322.parquet
# 2021-06-13 16:46:56       3100 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_hieHAfXugCu3QH83.parquet
# 2021-06-13 16:46:26       3268 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_iDQXOrqy0Ycx7das.parquet
# 2021-06-13 16:46:56       3221 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_k1T89yfTfz9PR3cQ.parquet
# 2021-06-13 16:46:57       3247 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_k8tF631ERNowTacY.parquet
# 2021-06-13 16:46:26       3419 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_kM7mipH5rvY8Gg3M.parquet
# 2021-06-13 16:46:56       3052 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_l9SaLrXQFArOGW9T.parquet
# 2021-06-13 16:46:56       3497 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_lvd2NHuyfVsTzfZ5.parquet
# 2021-06-13 16:46:56       3301 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_m4nBTAFkEc3ZxTFD.parquet
# 2021-06-13 16:46:56       3616 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_n7kELbOeiEKZcfg5.parquet
# 2021-06-13 16:46:57       3648 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_oFfQbR3WyE9tMj8V.parquet
# 2021-06-13 16:46:57       3272 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_obT4CN2qWlnJ5B4U.parquet
# 2021-06-13 16:46:55       3516 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_ouTswYbXAcI8B6vJ.parquet
# 2021-06-13 16:46:56       3450 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_pxaYKpX6oWCEiDk2.parquet
# 2021-06-13 16:46:54       3381 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_sQA8k0XJ6jedSdIq.parquet
# 2021-06-13 16:46:56       3318 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_scPCGNJkKuIvBtBO.parquet
# 2021-06-13 16:46:56       3247 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_vzZOGjCQLrtjtiT8.parquet
# 2021-06-13 16:46:56       3628 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623602409/data/year=2021/month=06/day=13/hour=16/20210613T163752Z_wGCkzrTvXC0DrDzO.parquet
# 2021-06-13 17:16:48          0 chapter07/input/581320662326/sagemaker/us-east-1/offline-store/cookbook-feature-group-1623604542/cookbook-feature-group2021-06-13T17:15:42.030Z.txt
# 2021-05-24 17:28:46     135348 chapter07/input/baseline_nl.csv
# 2021-06-13 16:49:12       3881 chapter07/input/test_data.csv
# 2021-06-13 16:49:15       3828 chapter07/input/test_data_no_header.csv
# 2021-05-30 09:03:01      45095 chapter07/input/test_features.csv
# 2021-06-13 16:49:11      11534 chapter07/input/training_data.csv
# 2021-06-13 16:49:14      11481 chapter07/input/training_data_no_header.csv
# 2021-06-13 16:49:12       3876 chapter07/input/validation_data.csv
# 2021-06-13 16:49:15       3823 chapter07/input/validation_data_no_header.csv

# %%
# %store -r s3_bucket_name
# %store -r prefix

# %%
base = f's3://{s3_bucket_name}/{prefix}'
output_location = f'{base}/query_results/'

print(output_location)
# Out:
# s3://sagemaker-cookbook-bucket/chapter07/query_results/

# %%
def query_data(query_string):
    print(f"QUERY: {query_string}\n")
    query = feature_group.athena_query()
    query.run(query_string=query_string, 
              output_location=output_location)
    
    query.wait()
    
    return query.as_dataframe()

# %%
from time import sleep

# wait for 5 minutes for the offline store to be ready
sleep(5 * 60)

# %%
query = f"""SELECT approved, sex, math, science, technology, random1, random2 FROM "{table}" ORDER BY index ASC LIMIT 600"""

training_df = query_data(query)
training_df
# Out:
# QUERY: SELECT approved, sex, math, science, technology, random1, random2 FROM "cookbook-feature-group-1623604542" ORDER BY index ASC LIMIT 600
#      approved  sex  math  science  technology  random1  random2
# 0           1    1    97       97          98       93       82
# 1           1    1    85       68          62       92       65
# 2           1    1    99      100          80       71       60
# 3           1    1    91       79          84       60       70
# 4           1    1    73       86          66       70       98
# ..        ...  ...   ...      ...         ...      ...      ...
# 595         1    1    99       86          85       98       87
# 596         1    1    71       97          90       86       99
# 597         1    1    95       86          62       69       73
# 598         1    1    78       71          68       72       68
# 599         1    1    89       82          65       97       83
#
# [600 rows x 7 columns]

# %%
query = f"""SELECT approved, sex, math, science, technology, random1, random2 FROM "{table}" WHERE index > 600 ORDER BY index ASC LIMIT 200"""

validation_df = query_data(query)
validation_df
# Out:
# QUERY: SELECT approved, sex, math, science, technology, random1, random2 FROM "cookbook-feature-group-1623604542" WHERE index > 600 ORDER BY index ASC LIMIT 200
#      approved  sex  math  science  technology  random1  random2
# 0           1    1    93       74          66       73       77
# 1           1    0    92       91          76       79       69
# 2           0    1    70       85          84       96       65
# 3           1    1    95       77          91       67       77
# 4           1    1    88       92          86       69       72
# ..        ...  ...   ...      ...         ...      ...      ...
# 195         1    1    63       94          91       94       94
# 196         1    1    99       83          99       94       69
# 197         1    0    84       77          99       90       77
# 198         1    1    87       64          75       80       95
# 199         0    0    79       65          75       80       83
#
# [200 rows x 7 columns]

# %%
query = f"""SELECT approved, sex, math, science, technology, random1, random2 FROM "{table}" WHERE index > 800 ORDER BY index ASC LIMIT 200 """

test_df = query_data(query)
test_df
# Out:
# QUERY: SELECT approved, sex, math, science, technology, random1, random2 FROM "cookbook-feature-group-1623604542" WHERE index > 800 ORDER BY index ASC LIMIT 200
#      approved  sex  math  science  technology  random1  random2
# 0           1    1    64       65          73       85       66
# 1           1    0    90       91          99       72       73
# 2           1    1    88       90          68       90      100
# 3           1    1    64       96          73       60       70
# 4           1    1    64       85          98       85       96
# ..        ...  ...   ...      ...         ...      ...      ...
# 195         1    0    99       62          92       71       75
# 196         1    0    85       74          91       69       63
# 197         1    1    72       99          86       61       65
# 198         1    1    79       89          79       98       80
# 199         1    1    72       97          79       87       60
#
# [200 rows x 7 columns]

# %%
# !mkdir -p tmp

# %%
training_df.to_csv('tmp/training_data.csv', 
                   header=True, 
                   index=False)
validation_df.to_csv('tmp/validation_data.csv', 
                     header=True, 
                     index=False)
test_df.to_csv('tmp/test_data.csv', 
               header=True, 
               index=False)

# %%
path = f"s3://{s3_bucket_name}/{prefix}"
training_data_path = f"{path}/input/training_data.csv"
validation_data_path = f"{path}/input/validation_data.csv"
test_data_path = f"{path}/input/test_data.csv"

# %%
# !aws s3 cp tmp/training_data.csv {training_data_path}
# !aws s3 cp tmp/validation_data.csv {validation_data_path}
# !aws s3 cp tmp/test_data.csv {test_data_path}
# Out:
# upload: tmp/training_data.csv to s3://sagemaker-cookbook-bucket/chapter07/input/training_data.csv
# upload: tmp/validation_data.csv to s3://sagemaker-cookbook-bucket/chapter07/input/validation_data.csv
# upload: tmp/test_data.csv to s3://sagemaker-cookbook-bucket/chapter07/input/test_data.csv

# %%
training_df.to_csv('tmp/training_data_no_header.csv', 
                   header=False, 
                   index=False)
validation_df.to_csv('tmp/validation_data_no_header.csv', 
                     header=False, 
                     index=False)
test_df.to_csv('tmp/test_data_no_header.csv', 
               header=False, 
               index=False)

# %%
training_data_path_nh = f"{path}/input/training_data_no_header.csv"
validation_data_path_nh = f"{path}/input/validation_data_no_header.csv"
test_data_path_nh = f"{path}/input/test_data_no_header.csv"

# %%
# !aws s3 cp tmp/training_data_no_header.csv {training_data_path_nh}
# !aws s3 cp tmp/validation_data_no_header.csv {validation_data_path_nh}
# !aws s3 cp tmp/test_data_no_header.csv {test_data_path_nh}
# Out:
# upload: tmp/training_data_no_header.csv to s3://sagemaker-cookbook-bucket/chapter07/input/training_data_no_header.csv
# upload: tmp/validation_data_no_header.csv to s3://sagemaker-cookbook-bucket/chapter07/input/validation_data_no_header.csv
# upload: tmp/test_data_no_header.csv to s3://sagemaker-cookbook-bucket/chapter07/input/test_data_no_header.csv

# %%
# %store training_data_path
# %store validation_data_path
# %store test_data_path
# %store training_data_path_nh
# %store validation_data_path_nh
# %store test_data_path_nh
# Out:
# Stored 'training_data_path' (str)
# Stored 'validation_data_path' (str)
# Stored 'test_data_path' (str)
# Stored 'training_data_path_nh' (str)
# Stored 'validation_data_path_nh' (str)
# Stored 'test_data_path_nh' (str)
