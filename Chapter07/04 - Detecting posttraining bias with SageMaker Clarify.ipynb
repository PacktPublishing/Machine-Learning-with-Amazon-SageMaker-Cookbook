# %%
# %store -r s3_bucket_name
# %store -r prefix
# %store -r training_data_path

# %%
import sagemaker

session = sagemaker.Session()
region = session.boto_region_name
role = sagemaker.get_execution_role()

# %%
s3_training_data_path = training_data_path
s3_output_path = f"s3://{s3_bucket_name}/{prefix}/output"

# %%
# !aws s3 cp {s3_training_data_path} tmp/training_data.csv
# Out:
# download: s3://sagemaker-cookbook-bucket/chapter07/input/training_data.csv to tmp/training_data.csv

# %%
import pandas as pd

training_data = pd.read_csv("tmp/training_data.csv")
training_data
# Out:
#       label          a          b   c   d
# 0         1  -8.837413  -6.551265  23 -75
# 1         1  -9.216749  -2.483494   2 -51
# 2         1  -2.017317  -6.326533  91  34
# 3         1 -10.748736  -4.622519   8 -78
# 4         0  -3.675848  12.629029  47  32
# ...     ...        ...        ...  ..  ..
# 2995      0  -5.786462  -6.790668 -65  70
# 2996      1  -2.552410  -1.793217  42   4
# 2997      0 -10.692197   1.583437 -90 -62
# 2998      1 -14.109003  -4.745680  37  64
# 2999      1  -8.801795  -5.552834  26  19
#
# [3000 rows x 5 columns]

# %%
from sagemaker.image_uris import retrieve

container = retrieve('xgboost', region, version='1.2-1')

# %%
from sagemaker.estimator import Estimator

estimator = Estimator(
    container,
    role,
    instance_count=1,
    instance_type='ml.m5.large',
    sagemaker_session=session
)

# %%
estimator.set_hyperparameters(
    objective='binary:logistic',
    max_depth=8,
    eta=0.1,
    min_child_weight=4,
    num_round=500
)

# %%
from sagemaker.inputs import TrainingInput

train_input = TrainingInput(
    s3_training_data_path, 
    content_type='csv'
)

# %%
# %%time

estimator.fit({'train': train_input}, wait='True')
# Out:
# 2021-05-24 14:02:25 Starting - Starting the training job...
# 2021-05-24 14:02:48 Starting - Launching requested ML instancesProfilerReport-1621864945: InProgress
# ......
# 2021-05-24 14:03:49 Starting - Preparing the instances for training.........
# 2021-05-24 14:05:09 Downloading - Downloading input data...
# 2021-05-24 14:05:49 Training - Downloading the training image..[2021-05-24 14:05:59.704 ip-10-2-124-51.ec2.internal:1 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# INFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Running XGBoost Sagemaker in algorithm mode
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Single node training.
# INFO:root:Train matrix has 3001 rows and 4 columns
# [0]#011train-error:0.13196
# [1]#011train-error:0.12562
# [2]#011train-error:0.12163
# [3]#011train-error:0.12329
# [4]#011train-error:0.12163
# [5]#011train-error:0.12096
# [6]#011train-error:0.12296
# [7]#011train-error:0.12296
# [8]#011train-error:0.11796
# [9]#011train-error:0.11696
# [10]#011train-error:0.11463
# [11]#011train-error:0.11496
# [12]#011train-error:0.11663
# [13]#011train-error:0.11863
# [14]#011train-error:0.11729
# [15]#011train-error:0.11729
# [16]#011train-error:0.11596
# [17]#011train-error:0.11563
# [18]#011train-error:0.11496
# [19]#011train-error:0.11496
# [20]#011train-error:0.11463
# [21]#011train-error:0.11396
# [22]#011train-error:0.11396
# [23]#011train-error:0.11296
# [24]#011train-error:0.11196
# [25]#011train-error:0.11330
# [26]#011train-error:0.11196
# [27]#011train-error:0.11096
# [28]#011train-error:0.11163
# [29]#011train-error:0.11096
# [30]#011train-error:0.11030
# [31]#011train-error:0.10963
# [32]#011train-error:0.10796
# [33]#011train-error:0.10730
# [34]#011train-error:0.10730
# [35]#011train-error:0.10696
# [36]#011train-error:0.10597
# [37]#011train-error:0.10630
# [38]#011train-error:0.10630
# [39]#011train-error:0.10663
# [40]#011train-error:0.10663
# [41]#011train-error:0.10663
# [42]#011train-error:0.10630
# [43]#011train-error:0.10597
# [44]#011train-error:0.10497
# [45]#011train-error:0.10430
# [46]#011train-error:0.10430
# [47]#011train-error:0.10297
# [48]#011train-error:0.10230
# [49]#011train-error:0.10197
# [50]#011train-error:0.10230
# [51]#011train-error:0.10130
# [52]#011train-error:0.10163
# [53]#011train-error:0.10097
# [54]#011train-error:0.10130
# [55]#011train-error:0.09963
# [56]#011train-error:0.09963
# [57]#011train-error:0.09797
# [58]#011train-error:0.09763
# [59]#011train-error:0.09763
# [60]#011train-error:0.09763
# [61]#011train-error:0.09697
# [62]#011train-error:0.09630
# [63]#011train-error:0.09530
# [64]#011train-error:0.09397
# [65]#011train-error:0.09363
# [66]#011train-error:0.09363
# [67]#011train-error:0.09297
# [68]#011train-error:0.09264
# [69]#011train-error:0.09297
# [70]#011train-error:0.09230
# [71]#011train-error:0.09264
# [72]#011train-error:0.09264
# [73]#011train-error:0.09197
# [74]#011train-error:0.09197
# [75]#011train-error:0.09230
# [76]#011train-error:0.09264
# [77]#011train-error:0.09230
# [78]#011train-error:0.09197
# [79]#011train-error:0.09197
# [80]#011train-error:0.09097
# [81]#011train-error:0.09064
# [82]#011train-error:0.08997
# [83]#011train-error:0.08964
# [84]#011train-error:0.08764
# [85]#011train-error:0.08830
# [86]#011train-error:0.08730
# [87]#011train-error:0.08631
# [88]#011train-error:0.08697
# [89]#011train-error:0.08764
# [90]#011train-error:0.08664
# [91]#011train-error:0.08564
# [92]#011train-error:0.08631
# [93]#011train-error:0.08631
# [94]#011train-error:0.08464
# [95]#011train-error:0.08397
# [96]#011train-error:0.08364
# [97]#011train-error:0.08364
# [98]#011train-error:0.08264
# [99]#011train-error:0.08297
# [100]#011train-error:0.08331
# [101]#011train-error:0.08297
# [102]#011train-error:0.08197
# [103]#011train-error:0.08264
# [104]#011train-error:0.08164
# [105]#011train-error:0.08164
# [106]#011train-error:0.08131
# [107]#011train-error:0.08131
# [108]#011train-error:0.08097
# [109]#011train-error:0.08031
# [110]#011train-error:0.07997
# [111]#011train-error:0.08031
# [112]#011train-error:0.08064
# [113]#011train-error:0.07931
# [114]#011train-error:0.07964
# [115]#011train-error:0.07964
# [116]#011train-error:0.07964
# [117]#011train-error:0.07964
# [118]#011train-error:0.07931
# [119]#011train-error:0.07897
# [120]#011train-error:0.07797
# [121]#011train-error:0.07864
# [122]#011train-error:0.07797
# [123]#011train-error:0.07797
# [124]#011train-error:0.07897
# [125]#011train-error:0.07831
# [126]#011train-error:0.07831
# [127]#011train-error:0.07931
# [128]#011train-error:0.07964
# [129]#011train-error:0.07964
# [130]#011train-error:0.07731
# [131]#011train-error:0.07764
# [132]#011train-error:0.07697
# [133]#011train-error:0.07631
# [134]#011train-error:0.07598
# [135]#011train-error:0.07531
# [136]#011train-error:0.07497
# [137]#011train-error:0.07531
# [138]#011train-error:0.07464
# [139]#011train-error:0.07397
# [140]#011train-error:0.07397
# [141]#011train-error:0.07331
# [142]#011train-error:0.07264
# [143]#011train-error:0.07264
# [144]#011train-error:0.07231
# [145]#011train-error:0.07198
# [146]#011train-error:0.07231
# [147]#011train-error:0.07131
# [148]#011train-error:0.07064
# [149]#011train-error:0.07098
# [150]#011train-error:0.07098
# [151]#011train-error:0.07031
# [152]#011train-error:0.06998
# [153]#011train-error:0.06964
# [154]#011train-error:0.06898
# [155]#011train-error:0.06731
# [156]#011train-error:0.06698
# [157]#011train-error:0.06831
# [158]#011train-error:0.06698
# [159]#011train-error:0.06631
# [160]#011train-error:0.06598
# [161]#011train-error:0.06598
# [162]#011train-error:0.06598
# [163]#011train-error:0.06631
# [164]#011train-error:0.06498
# [165]#011train-error:0.06498
# [166]#011train-error:0.06464
# [167]#011train-error:0.06431
# [168]#011train-error:0.06464
# [169]#011train-error:0.06431
# [170]#011train-error:0.06464
# [171]#011train-error:0.06464
# [172]#011train-error:0.06431
# [173]#011train-error:0.06364
# [174]#011train-error:0.06364
# [175]#011train-error:0.06298
# [176]#011train-error:0.06231
# [177]#011train-error:0.06231
# [178]#011train-error:0.06231
# [179]#011train-error:0.06098
# [180]#011train-error:0.06098
# [181]#011train-error:0.06065
# [182]#011train-error:0.06065
# [183]#011train-error:0.06065
# [184]#011train-error:0.06098
# [185]#011train-error:0.05998
# [186]#011train-error:0.05998
# [187]#011train-error:0.05998
# [188]#011train-error:0.05998
# [189]#011train-error:0.05831
# [190]#011train-error:0.05898
# [191]#011train-error:0.05865
# [192]#011train-error:0.05731
# [193]#011train-error:0.05731
# [194]#011train-error:0.05731
# [195]#011train-error:0.05798
# [196]#011train-error:0.05565
# [197]#011train-error:0.05565
# [198]#011train-error:0.05565
# [199]#011train-error:0.05565
# [200]#011train-error:0.05398
# [201]#011train-error:0.05432
# [202]#011train-error:0.05365
# [203]#011train-error:0.05332
# [204]#011train-error:0.05265
# [205]#011train-error:0.05232
# [206]#011train-error:0.05165
# [207]#011train-error:0.05198
# [208]#011train-error:0.05098
# [209]#011train-error:0.05065
# [210]#011train-error:0.05065
# [211]#011train-error:0.05032
# [212]#011train-error:0.04998
# [213]#011train-error:0.04898
# [214]#011train-error:0.04898
# [215]#011train-error:0.04865
# [216]#011train-error:0.04898
# [217]#011train-error:0.04965
# [218]#011train-error:0.04898
# [219]#011train-error:0.04732
# [220]#011train-error:0.04632
# [221]#011train-error:0.04632
# [222]#011train-error:0.04632
# [223]#011train-error:0.04665
# [224]#011train-error:0.04665
# [225]#011train-error:0.04665
# [226]#011train-error:0.04632
# [227]#011train-error:0.04632
# [228]#011train-error:0.04665
# [229]#011train-error:0.04565
# [230]#011train-error:0.04598
# [231]#011train-error:0.04565
# [232]#011train-error:0.04465
# [233]#011train-error:0.04432
# [234]#011train-error:0.04432
# [235]#011train-error:0.04365
# [236]#011train-error:0.04399
# [237]#011train-error:0.04299
# [238]#011train-error:0.04265
# [239]#011train-error:0.04265
# [240]#011train-error:0.04265
# [241]#011train-error:0.04265
# [242]#011train-error:0.04132
# [243]#011train-error:0.04132
# [244]#011train-error:0.04199
# [245]#011train-error:0.04165
# [246]#011train-error:0.04132
# [247]#011train-error:0.04065
# [248]#011train-error:0.04099
# [249]#011train-error:0.04032
# [250]#011train-error:0.03999
# [251]#011train-error:0.04032
# [252]#011train-error:0.04032
# [253]#011train-error:0.04032
# [254]#011train-error:0.04065
# [255]#011train-error:0.04065
# [256]#011train-error:0.03965
# [257]#011train-error:0.03999
# [258]#011train-error:0.03799
# [259]#011train-error:0.03732
# [260]#011train-error:0.03699
# [261]#011train-error:0.03699
# [262]#011train-error:0.03699
# [263]#011train-error:0.03665
# [264]#011train-error:0.03665
# [265]#011train-error:0.03632
# [266]#011train-error:0.03665
# [267]#011train-error:0.03632
# [268]#011train-error:0.03599
# [269]#011train-error:0.03632
# [270]#011train-error:0.03565
# [271]#011train-error:0.03565
# [272]#011train-error:0.03599
# [273]#011train-error:0.03632
# [274]#011train-error:0.03632
# [275]#011train-error:0.03565
# [276]#011train-error:0.03632
# [277]#011train-error:0.03632
# [278]#011train-error:0.03665
# [279]#011train-error:0.03632
# [280]#011train-error:0.03599
# [281]#011train-error:0.03599
# [282]#011train-error:0.03632
# [283]#011train-error:0.03532
# [284]#011train-error:0.03465
# [285]#011train-error:0.03465
# [286]#011train-error:0.03465
# [287]#011train-error:0.03432
# [288]#011train-error:0.03365
# [289]#011train-error:0.03232
# [290]#011train-error:0.03266
# [291]#011train-error:0.03266
# [292]#011train-error:0.03232
# [293]#011train-error:0.03266
# [294]#011train-error:0.03166
# [295]#011train-error:0.03132
# [296]#011train-error:0.03232
# [297]#011train-error:0.03199
# [298]#011train-error:0.03199
# [299]#011train-error:0.03199
# [300]#011train-error:0.03166
# [301]#011train-error:0.03166
# [302]#011train-error:0.03166
# [303]#011train-error:0.03066
# [304]#011train-error:0.03099
# [305]#011train-error:0.03066
# [306]#011train-error:0.03099
# [307]#011train-error:0.03066
# [308]#011train-error:0.03099
# [309]#011train-error:0.03099
# [310]#011train-error:0.03099
# [311]#011train-error:0.03066
# [312]#011train-error:0.02999
# [313]#011train-error:0.02999
# [314]#011train-error:0.02999
# [315]#011train-error:0.02966
# [316]#011train-error:0.02932
# [317]#011train-error:0.02832
# [318]#011train-error:0.02832
# [319]#011train-error:0.02832
# [320]#011train-error:0.02832
# [321]#011train-error:0.02832
# [322]#011train-error:0.02832
# [323]#011train-error:0.02832
# [324]#011train-error:0.02832
# [325]#011train-error:0.02799
# [326]#011train-error:0.02699
# [327]#011train-error:0.02732
# [328]#011train-error:0.02666
# [329]#011train-error:0.02633
# [330]#011train-error:0.02633
# [331]#011train-error:0.02633
# [332]#011train-error:0.02633
# [333]#011train-error:0.02566
# [334]#011train-error:0.02566
# [335]#011train-error:0.02566
# [336]#011train-error:0.02599
# [337]#011train-error:0.02633
# [338]#011train-error:0.02566
# [339]#011train-error:0.02566
# [340]#011train-error:0.02599
# [341]#011train-error:0.02566
# [342]#011train-error:0.02533
# [343]#011train-error:0.02499
# [344]#011train-error:0.02533
# [345]#011train-error:0.02599
# [346]#011train-error:0.02566
# [347]#011train-error:0.02499
# [348]#011train-error:0.02432
# [349]#011train-error:0.02466
# [350]#011train-error:0.02399
# [351]#011train-error:0.02399
# [352]#011train-error:0.02299
# [353]#011train-error:0.02299
# [354]#011train-error:0.02299
# [355]#011train-error:0.02266
# [356]#011train-error:0.02299
# [357]#011train-error:0.02299
# [358]#011train-error:0.02199
# [359]#011train-error:0.02199
# [360]#011train-error:0.02166
# [361]#011train-error:0.02199
# [362]#011train-error:0.02199
# [363]#011train-error:0.02166
# [364]#011train-error:0.02233
# [365]#011train-error:0.02199
# [366]#011train-error:0.02133
# [367]#011train-error:0.02133
# [368]#011train-error:0.02099
# [369]#011train-error:0.02133
# [370]#011train-error:0.02133
# [371]#011train-error:0.02133
# [372]#011train-error:0.02133
# [373]#011train-error:0.02099
# [374]#011train-error:0.02099
# [375]#011train-error:0.02033
# [376]#011train-error:0.01999
# [377]#011train-error:0.01999
# [378]#011train-error:0.01933
# [379]#011train-error:0.01899
# [380]#011train-error:0.01899
# [381]#011train-error:0.01899
# [382]#011train-error:0.01899
# [383]#011train-error:0.01866
# [384]#011train-error:0.01833
# [385]#011train-error:0.01933
# [386]#011train-error:0.01833
# [387]#011train-error:0.01833
# [388]#011train-error:0.01766
# [389]#011train-error:0.01766
# [390]#011train-error:0.01799
# [391]#011train-error:0.01699
# [392]#011train-error:0.01733
# [393]#011train-error:0.01733
# [394]#011train-error:0.01699
# [395]#011train-error:0.01699
# [396]#011train-error:0.01666
# [397]#011train-error:0.01666
# [398]#011train-error:0.01666
# [399]#011train-error:0.01666
# [400]#011train-error:0.01699
# [401]#011train-error:0.01666
# [402]#011train-error:0.01666
# [403]#011train-error:0.01699
# [404]#011train-error:0.01699
# [405]#011train-error:0.01666
# [406]#011train-error:0.01666
# [407]#011train-error:0.01666
# [408]#011train-error:0.01699
# [409]#011train-error:0.01666
# [410]#011train-error:0.01666
# [411]#011train-error:0.01699
# [412]#011train-error:0.01633
# [413]#011train-error:0.01633
# [414]#011train-error:0.01633
# [415]#011train-error:0.01633
# [416]#011train-error:0.01599
# [417]#011train-error:0.01599
# [418]#011train-error:0.01533
# [419]#011train-error:0.01499
# [420]#011train-error:0.01499
# [421]#011train-error:0.01533
# [422]#011train-error:0.01499
# [423]#011train-error:0.01499
# [424]#011train-error:0.01499
# [425]#011train-error:0.01466
# [426]#011train-error:0.01499
# [427]#011train-error:0.01499
# [428]#011train-error:0.01499
# [429]#011train-error:0.01433
# [430]#011train-error:0.01466
# [431]#011train-error:0.01533
# [432]#011train-error:0.01499
# [433]#011train-error:0.01400
# [434]#011train-error:0.01433
# [435]#011train-error:0.01433
# [436]#011train-error:0.01466
# [437]#011train-error:0.01466
# [438]#011train-error:0.01466
# [439]#011train-error:0.01433
# [440]#011train-error:0.01433
# [441]#011train-error:0.01366
# [442]#011train-error:0.01366
# [443]#011train-error:0.01333
# [444]#011train-error:0.01333
# [445]#011train-error:0.01300
# [446]#011train-error:0.01300
# [447]#011train-error:0.01366
# [448]#011train-error:0.01366
# [449]#011train-error:0.01366
# [450]#011train-error:0.01300
# [451]#011train-error:0.01266
# [452]#011train-error:0.01266
# [453]#011train-error:0.01266
# [454]#011train-error:0.01266
# [455]#011train-error:0.01300
# [456]#011train-error:0.01266
# [457]#011train-error:0.01200
# [458]#011train-error:0.01200
# [459]#011train-error:0.01166
# [460]#011train-error:0.01166
# [461]#011train-error:0.01166
# [462]#011train-error:0.01100
# [463]#011train-error:0.01133
# [464]#011train-error:0.01166
# [465]#011train-error:0.01100
# [466]#011train-error:0.01100
# [467]#011train-error:0.01100
# [468]#011train-error:0.01066
# [469]#011train-error:0.01066
# [470]#011train-error:0.01066
# [471]#011train-error:0.01100
# [472]#011train-error:0.01100
# [473]#011train-error:0.01100
# [474]#011train-error:0.01066
# [475]#011train-error:0.01066
# [476]#011train-error:0.01066
# [477]#011train-error:0.01066
# [478]#011train-error:0.01066
# [479]#011train-error:0.01066
# [480]#011train-error:0.01066
# [481]#011train-error:0.01066
# [482]#011train-error:0.01033
# [483]#011train-error:0.01033
# [484]#011train-error:0.01033
# [485]#011train-error:0.01000
# [486]#011train-error:0.01033
# [487]#011train-error:0.01066
# [488]#011train-error:0.01000
# [489]#011train-error:0.00966
# [490]#011train-error:0.00966
# [491]#011train-error:0.00966
# [492]#011train-error:0.00966
# [493]#011train-error:0.00933
# [494]#011train-error:0.00900
# [495]#011train-error:0.00900
# [496]#011train-error:0.00933
# [497]#011train-error:0.00866
# [498]#011train-error:0.00833
# [499]#011train-error:0.00866
#
# 2021-05-24 14:06:12 Uploading - Uploading generated training model
# 2021-05-24 14:06:12 Completed - Training job completed
# Training seconds: 63
# Billable seconds: 63
# CPU times: user 609 ms, sys: 62.6 ms, total: 671 ms
# Wall time: 4min 12s

# %%
import random
from string import ascii_uppercase

def generate_model_name():
    chars = random.choices(ascii_uppercase, k=5)
    output = 'model-' + ''.join(chars)
    return output

# %%
model_name = generate_model_name()
model_name
# Out:
# 'model-ACBOE'

# %%
model = estimator.create_model(name=model_name)

# %%
type(model)
# Out:
# sagemaker.model.Model

# %%
model.__dict__
# Out:
# {'model_data': 's3://sagemaker-us-east-1-581320662326/sagemaker-xgboost-2021-05-24-14-02-24-886/output/model.tar.gz',
#  'image_uri': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.2-1',
#  'role': 'arn:aws:iam::581320662326:role/SuperAdminRole',
#  'predictor_cls': <function sagemaker.estimator.Estimator.create_model.<locals>.predict_wrapper(endpoint, session)>,
#  'env': {},
#  'name': 'model-ACBOE',
#  '_base_name': None,
#  'vpc_config': None,
#  'sagemaker_session': <sagemaker.session.Session at 0x7fe5d010b5d0>,
#  'endpoint_name': None,
#  '_is_compiled_model': False,
#  '_compilation_job_name': None,
#  '_is_edge_packaged_model': False,
#  '_enable_network_isolation': False,
#  'model_kms_key': None,
#  'image_config': None}

# %%
container_def = model.prepare_container_def()
container_def
# Out:
# {'Image': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.2-1',
#  'Environment': {},
#  'ModelDataUrl': 's3://sagemaker-us-east-1-581320662326/sagemaker-xgboost-2021-05-24-14-02-24-886/output/model.tar.gz'}

# %%
session.create_model(
    model_name,
    role,
    container_def
)
# Out:
# 'model-ACBOE'

# %%
from sagemaker.clarify import SageMakerClarifyProcessor

processor = SageMakerClarifyProcessor(
    role=role,                                                  
    instance_count=1,                                                  
    instance_type='ml.m5.large',
    sagemaker_session=session
)

# %%
from sagemaker.clarify import DataConfig

data_config = DataConfig(
    s3_data_input_path=s3_training_data_path,
    s3_output_path=s3_output_path,
    label='label',
    headers=training_data.columns.to_list(),
    dataset_type='text/csv'
)

data_config.__dict__
# Out:
# {'s3_data_input_path': 's3://sagemaker-cookbook-bucket/chapter07/input/training_data.csv',
#  's3_output_path': 's3://sagemaker-cookbook-bucket/chapter07/output',
#  's3_data_distribution_type': 'FullyReplicated',
#  's3_compression_type': 'None',
#  'label': 'label',
#  'headers': ['label', 'a', 'b', 'c', 'd'],
#  'features': None,
#  'analysis_config': {'dataset_type': 'text/csv',
#   'headers': ['label', 'a', 'b', 'c', 'd'],
#   'label': 'label'}}

# %%
from sagemaker.clarify import ModelConfig

model_config = ModelConfig(
    model_name=model_name,
    instance_type='ml.c5.xlarge',
    instance_count=1,
    accept_type='text/csv'
)

# %%
from sagemaker.clarify import ModelPredictedLabelConfig

predictions_config = ModelPredictedLabelConfig(
    probability_threshold=0.75
)

# %%
from sagemaker.clarify import BiasConfig

bias_config = BiasConfig(
    label_values_or_threshold=[1],              
    facet_name='a',                             
    facet_values_or_threshold=[5]
)

# %%
# %%time

processor.run_post_training_bias(
    data_config=data_config, 
    data_bias_config=bias_config,
    methods=['DPPL', 'RD'],
    model_config=model_config,
    model_predicted_label_config=predictions_config
)
# Out:
# Job Name:  Clarify-Posttraining-Bias-2021-05-24-14-20-24-904
# Inputs:  [{'InputName': 'dataset', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-cookbook-bucket/chapter07/input/training_data.csv', 'LocalPath': '/opt/ml/processing/input/data', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}, {'InputName': 'analysis_config', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-cookbook-bucket/chapter07/output/analysis_config.json', 'LocalPath': '/opt/ml/processing/input/config', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}]
# Outputs:  [{'OutputName': 'analysis_result', 'AppManaged': False, 'S3Output': {'S3Uri': 's3://sagemaker-cookbook-bucket/chapter07/output', 'LocalPath': '/opt/ml/processing/output', 'S3UploadMode': 'EndOfJob'}}]
# ...............................INFO:sagemaker-clarify-processing:Starting SageMaker Clarify Processing job
# INFO:analyzer.data_loading.data_loader_util:Analysis config path: /opt/ml/processing/input/config
# INFO:analyzer.data_loading.data_loader_util:Analysis result path: /opt/ml/processing/output
# INFO:analyzer.data_loading.data_loader_util:This host is algo-1.
# INFO:analyzer.data_loading.data_loader_util:This host is the leader.
# INFO:analyzer.data_loading.data_loader_util:Number of hosts in the cluster is 1.
# INFO:sagemaker-clarify-processing:Running Python / Pandas based analyzer.
# INFO:analyzer.data_loading.data_loader_util:Dataset uri: /opt/ml/processing/input/data
# INFO:analyzer.data_loading.data_loader_util:Dataset type: text/csv
# INFO:analyzer.predictor:Spinning up shadow endpoint
# INFO:sagemaker:Creating endpoint-config with name sagemaker-clarify-endpoint-config-1621866324-3c45
# INFO:analyzer.predictor:Creating endpoint sagemaker-clarify-endpoint-1621866324-a61b
# INFO:sagemaker-clarify-processing:======================================
# INFO:sagemaker-clarify-processing:Calculating post-training bias metrics
# INFO:sagemaker-clarify-processing:======================================
# INFO:sagemaker-clarify-processing:Getting predictions from the endpoint
# INFO:analyzer.predictor:Checking endpoint status
# INFO:analyzer.predictor:Endpoint is in service after 421 seconds
# INFO:analyzer.predictor:Prediction batch size is initialized with 128397
# INFO:analyzer.prediction_util:We assume a prediction above 0.750 indicates 1 and below or equal indicates 0.
# INFO:smclarify.bias.metrics.common:data uniqueness fraction: 0.0006666666666666666
# INFO:smclarify.bias.metrics.common:data uniqueness fraction: 0.0006666666666666666
# INFO:smclarify.bias.metrics.common:data uniqueness fraction: 0.0006666666666666666
# INFO:smclarify.bias.metrics.common:data uniqueness fraction: 0.0006666666666666666
# INFO:smclarify.bias.metrics.common:data uniqueness fraction: 1.0
# INFO:smclarify.bias.report:Threshold Interval indices: IntervalIndex([(5.0, 13.99152988349206]],
#               closed='right',
#               dtype='interval[float64]')
# INFO:analyzer.predictor:Stop using endpoint: sagemaker-clarify-endpoint-1621866324-a61b
# INFO:sagemaker:Deleting endpoint configuration with name: sagemaker-clarify-endpoint-config-1621866324-3c45
# INFO:sagemaker:Deleting endpoint with name: sagemaker-clarify-endpoint-1621866324-a61b
# INFO:analyzer.predictor:Model endpoint delivered 2.05909 requests per second and a total of 1 requests over 0 seconds
# INFO:analyzer.predictor:Delivered 1 predict calls with a total of 3000 examples.
# INFO:analyzer.predictor:Stop using endpoint: None
# INFO:analyzer.predictor:Delivered 1 predict calls with a total of 3000 examples.
# [NbConvertApp] Converting notebook /opt/ml/processing/output/report.ipynb to html
# [NbConvertApp] Writing 274115 bytes to /opt/ml/processing/output/report.html
# INFO:analyzer.report:HTML report '/opt/ml/processing/output/report.html' generated successfully.
# INFO:analyzer.report:PDF report '/opt/ml/processing/output/report.pdf' generated successfully.
# INFO:sagemaker-clarify-processing:Collected analyses:
# {
#     "version": "1.0",
#     "post_training_bias_metrics": {
#         "label": "label",
#         "facets": {
#             "a": [
#                 {
#                     "value_or_threshold": "(5.0, 13.99152988349206]",
#                     "metrics": [
#                         {
#                             "name": "DPPL",
#                             "description": "Difference in Positive Proportions in Predicted Labels (DPPL)",
#                             "value": 0.483991825613079
#                         },
#                         {
#                             "name": "RD",
#                             "description": "Recall Difference (RD)",
#                             "value": 0.9460719041278296
#                         }
#                     ]
#                 }
#             ]
#         },
#         "label_value_or_threshold": "1"
#     }
# }
# INFO:analyzer.system_util:exit_message: Completed: SageMaker XAI Analyzer ran successfully
# -------!
#
# CPU times: user 1.4 s, sys: 124 ms, total: 1.52 s
# Wall time: 12min 53s

# %%
output = processor.latest_job.outputs[0]
output_destination = output.destination
output_destination
# Out:
# 's3://sagemaker-cookbook-bucket/chapter07/output'

# %%
# !aws s3 cp {output_destination}/ tmp/ --recursive
# Out:
# download: s3://sagemaker-cookbook-bucket/chapter07/output/analysis_config.json to tmp/analysis_config.json
# download: s3://sagemaker-cookbook-bucket/chapter07/output/analysis.json to tmp/analysis.json
# download: s3://sagemaker-cookbook-bucket/chapter07/output/report.pdf to tmp/report.pdf
# download: s3://sagemaker-cookbook-bucket/chapter07/output/report.ipynb to tmp/report.ipynb
# download: s3://sagemaker-cookbook-bucket/chapter07/output/report.html to tmp/report.html

# %%
# !ls -lahF tmp/
# Out:
# total 840K
# drwxr-xr-x 2 root root 6.0K May 24 14:34 ./
# drwxr-xr-x 4 root root 6.0K May 24 14:33 ../
# -rw-r--r-- 1 root root  837 May 24 14:32 analysis.json
# -rw-r--r-- 1 root root  470 May 24 14:20 analysis_config.json
# -rw-r--r-- 1 root root 268K May 24 14:32 report.html
# -rw-r--r-- 1 root root 1.5K May 24 14:32 report.ipynb
# -rw-r--r-- 1 root root  29K May 24 14:32 report.pdf
# -rw-r--r-- 1 root root  46K May 24 13:26 test_data.csv
# -rw-r--r-- 1 root root  46K May 24 13:26 test_data_no_header.csv
# -rw-r--r-- 1 root root  45K May 24 14:32 test_features.csv
# -rw-r--r-- 1 root root 139K May 24 13:26 training_data.csv
# -rw-r--r-- 1 root root 139K May 24 13:26 training_data_no_header.csv
# -rw-r--r-- 1 root root  47K May 24 13:26 validation_data.csv
# -rw-r--r-- 1 root root  47K May 24 13:26 validation_data_no_header.csv

# %%
# !cat tmp/analysis.json
# Out:
# {
#     "version": "1.0",
#     "post_training_bias_metrics": {
#         "label": "label",
#         "facets": {
#             "a": [
#                 {
#                     "value_or_threshold": "(5.0, 13.99152988349206]",
#                     "metrics": [
#                         {
#                             "name": "DPPL",
#                             "description": "Difference in Positive Proportions in Predicted Labels (DPPL)",
#                             "value": 0.483991825613079
#                         },
#                         {
#                             "name": "RD",
#                             "description": "Recall Difference (RD)",
#                             "value": 0.9460719041278296
#                         }
#                     ]
#                 }
#             ]
#         },
#         "label_value_or_threshold": "1"
#     }
# }

# %%
# %store model_name
model_name
# Out:
# Stored 'model_name' (str)
# 'model-ACBOE'
