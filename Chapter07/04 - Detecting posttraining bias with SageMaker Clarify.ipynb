# %%
# %store -r s3_bucket_name
# %store -r prefix
# %store -r training_data_path

# %%
import sagemaker

session = sagemaker.Session()
region = session.boto_region_name
role = sagemaker.get_execution_role()

# %%
s3_training_data_path = training_data_path
s3_output_path = f"s3://{s3_bucket_name}/{prefix}/output"

# %%
# !aws s3 cp {s3_training_data_path} tmp/training_data.csv
# Out:
# download: s3://sagemaker-cookbook-bucket/chapter07/input/training_data.csv to tmp/training_data.csv

# %%
import pandas as pd

training_data = pd.read_csv("tmp/training_data.csv")
training_data
# Out:
#      approved  sex  math  science  technology  random1  random2
# 0           1    1    97       97          98       93       82
# 1           1    1    85       68          62       92       65
# 2           1    1    99      100          80       71       60
# 3           1    1    91       79          84       60       70
# 4           1    1    73       86          66       70       98
# ..        ...  ...   ...      ...         ...      ...      ...
# 595         1    1    99       86          85       98       87
# 596         1    1    71       97          90       86       99
# 597         1    1    95       86          62       69       73
# 598         1    1    78       71          68       72       68
# 599         1    1    89       82          65       97       83
#
# [600 rows x 7 columns]

# %%
from sagemaker.image_uris import retrieve

container = retrieve('xgboost', region, version='1.2-1')

# %%
from sagemaker.estimator import Estimator

estimator = Estimator(
    container,
    role,
    instance_count=1,
    instance_type='ml.m5.large',
    sagemaker_session=session
)

# %%
estimator.set_hyperparameters(
    objective='binary:logistic',
    max_depth=8,
    eta=0.1,
    min_child_weight=4,
    num_round=500
)

# %%
from sagemaker.inputs import TrainingInput

train_input = TrainingInput(
    s3_training_data_path, 
    content_type='csv'
)

# %%
# %%time

estimator.fit({'train': train_input}, wait='True')
# Out:
# 2021-06-13 17:34:37 Starting - Starting the training job...
# 2021-06-13 17:34:47 Starting - Launching requested ML instancesProfilerReport-1623605677: InProgress
# ......
# 2021-06-13 17:35:56 Starting - Preparing the instances for training.........
# 2021-06-13 17:37:29 Downloading - Downloading input data...
# 2021-06-13 17:37:49 Training - Downloading the training image..[2021-06-13 17:38:17.543 ip-10-2-126-138.ec2.internal:1 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# INFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Running XGBoost Sagemaker in algorithm mode
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Single node training.
# INFO:root:Train matrix has 601 rows and 6 columns
# [0]#011train-error:0.14143
# [1]#011train-error:0.12646
# [2]#011train-error:0.12313
# [3]#011train-error:0.12313
# [4]#011train-error:0.12479
# [5]#011train-error:0.12479
# [6]#011train-error:0.12479
# [7]#011train-error:0.12479
# [8]#011train-error:0.11481
# [9]#011train-error:0.11481
# [10]#011train-error:0.11481
# [11]#011train-error:0.11314
# [12]#011train-error:0.10982
# [13]#011train-error:0.11481
# [14]#011train-error:0.11314
# [15]#011train-error:0.11314
# [16]#011train-error:0.11148
# [17]#011train-error:0.10982
# [18]#011train-error:0.10649
# [19]#011train-error:0.10150
# [20]#011train-error:0.10150
# [21]#011train-error:0.09983
# [22]#011train-error:0.09817
# [23]#011train-error:0.09817
# [24]#011train-error:0.09651
# [25]#011train-error:0.09651
# [26]#011train-error:0.09151
# [27]#011train-error:0.09318
# [28]#011train-error:0.08819
# [29]#011train-error:0.08819
# [30]#011train-error:0.08819
# [31]#011train-error:0.08819
# [32]#011train-error:0.08486
# [33]#011train-error:0.08652
# [34]#011train-error:0.08486
# [35]#011train-error:0.08486
# [36]#011train-error:0.08153
# [37]#011train-error:0.08153
# [38]#011train-error:0.07987
# [39]#011train-error:0.07987
# [40]#011train-error:0.07987
# [41]#011train-error:0.07820
# [42]#011train-error:0.07987
# [43]#011train-error:0.07820
# [44]#011train-error:0.07654
# [45]#011train-error:0.07820
# [46]#011train-error:0.07820
# [47]#011train-error:0.07820
# [48]#011train-error:0.07654
# [49]#011train-error:0.07321
# [50]#011train-error:0.07321
# [51]#011train-error:0.06822
# [52]#011train-error:0.06988
# [53]#011train-error:0.07155
# [54]#011train-error:0.06988
# [55]#011train-error:0.06822
# [56]#011train-error:0.06489
# [57]#011train-error:0.06656
# [58]#011train-error:0.06822
# [59]#011train-error:0.06489
# [60]#011train-error:0.06489
# [61]#011train-error:0.06656
# [62]#011train-error:0.06489
# [63]#011train-error:0.06656
# [64]#011train-error:0.06656
# [65]#011train-error:0.06489
# [66]#011train-error:0.06323
# [67]#011train-error:0.05990
# [68]#011train-error:0.05657
# [69]#011train-error:0.05491
# [70]#011train-error:0.05491
# [71]#011train-error:0.05491
# [72]#011train-error:0.05491
# [73]#011train-error:0.05325
# [74]#011train-error:0.05325
# [75]#011train-error:0.05325
# [76]#011train-error:0.05325
# [77]#011train-error:0.05325
# [78]#011train-error:0.05158
# [79]#011train-error:0.05325
# [80]#011train-error:0.05491
# [81]#011train-error:0.05325
# [82]#011train-error:0.05325
# [83]#011train-error:0.05158
# [84]#011train-error:0.04992
# [85]#011train-error:0.04992
# [86]#011train-error:0.04992
# [87]#011train-error:0.04825
# [88]#011train-error:0.04659
# [89]#011train-error:0.04825
# [90]#011train-error:0.04825
# [91]#011train-error:0.04492
# [92]#011train-error:0.04992
# [93]#011train-error:0.04825
# [94]#011train-error:0.04825
# [95]#011train-error:0.04659
# [96]#011train-error:0.04825
# [97]#011train-error:0.04825
# [98]#011train-error:0.04659
# [99]#011train-error:0.04492
# [100]#011train-error:0.04659
# [101]#011train-error:0.04492
# [102]#011train-error:0.04160
# [103]#011train-error:0.04160
# [104]#011train-error:0.04160
# [105]#011train-error:0.04160
# [106]#011train-error:0.04326
# [107]#011train-error:0.03993
# [108]#011train-error:0.03993
# [109]#011train-error:0.04160
# [110]#011train-error:0.03993
# [111]#011train-error:0.03993
# [112]#011train-error:0.03993
# [113]#011train-error:0.03993
# [114]#011train-error:0.03993
# [115]#011train-error:0.03827
# [116]#011train-error:0.03827
# [117]#011train-error:0.03661
# [118]#011train-error:0.03827
# [119]#011train-error:0.03827
# [120]#011train-error:0.03661
# [121]#011train-error:0.03494
# [122]#011train-error:0.03161
# [123]#011train-error:0.03161
# [124]#011train-error:0.03161
# [125]#011train-error:0.03161
# [126]#011train-error:0.03328
# [127]#011train-error:0.03161
# [128]#011train-error:0.03161
# [129]#011train-error:0.03161
# [130]#011train-error:0.02995
# [131]#011train-error:0.02995
# [132]#011train-error:0.02829
# [133]#011train-error:0.02829
# [134]#011train-error:0.02995
# [135]#011train-error:0.02829
# [136]#011train-error:0.02829
# [137]#011train-error:0.02829
# [138]#011train-error:0.02995
# [139]#011train-error:0.02662
# [140]#011train-error:0.02662
# [141]#011train-error:0.02662
# [142]#011train-error:0.02662
# [143]#011train-error:0.02496
# [144]#011train-error:0.02496
# [145]#011train-error:0.02496
# [146]#011train-error:0.02496
# [147]#011train-error:0.02496
# [148]#011train-error:0.02496
# [149]#011train-error:0.02496
# [150]#011train-error:0.02496
# [151]#011train-error:0.02329
# [152]#011train-error:0.02329
# [153]#011train-error:0.02329
# [154]#011train-error:0.02329
# [155]#011train-error:0.02329
# [156]#011train-error:0.02329
# [157]#011train-error:0.02329
# [158]#011train-error:0.01997
# [159]#011train-error:0.01997
# [160]#011train-error:0.01997
# [161]#011train-error:0.01997
# [162]#011train-error:0.01997
# [163]#011train-error:0.01997
# [164]#011train-error:0.01997
# [165]#011train-error:0.01997
# [166]#011train-error:0.01997
# [167]#011train-error:0.01997
# [168]#011train-error:0.01997
# [169]#011train-error:0.01997
# [170]#011train-error:0.01997
# [171]#011train-error:0.01997
# [172]#011train-error:0.01997
# [173]#011train-error:0.01997
# [174]#011train-error:0.01997
# [175]#011train-error:0.01997
# [176]#011train-error:0.01997
# [177]#011train-error:0.01997
# [178]#011train-error:0.01997
# [179]#011train-error:0.01997
# [180]#011train-error:0.01997
# [181]#011train-error:0.01997
# [182]#011train-error:0.01997
# [183]#011train-error:0.01997
# [184]#011train-error:0.01997
# [185]#011train-error:0.01830
# [186]#011train-error:0.01830
# [187]#011train-error:0.01830
# [188]#011train-error:0.01664
# [189]#011train-error:0.01664
# [190]#011train-error:0.01830
# [191]#011train-error:0.01830
# [192]#011train-error:0.01664
# [193]#011train-error:0.01664
# [194]#011train-error:0.01664
# [195]#011train-error:0.01664
# [196]#011train-error:0.01498
# [197]#011train-error:0.01498
# [198]#011train-error:0.01498
# [199]#011train-error:0.01498
# [200]#011train-error:0.01498
# [201]#011train-error:0.01498
# [202]#011train-error:0.01498
# [203]#011train-error:0.01498
# [204]#011train-error:0.01498
# [205]#011train-error:0.01498
# [206]#011train-error:0.01498
# [207]#011train-error:0.01331
# [208]#011train-error:0.01331
# [209]#011train-error:0.01331
# [210]#011train-error:0.01165
# [211]#011train-error:0.01165
# [212]#011train-error:0.01165
# [213]#011train-error:0.01165
# [214]#011train-error:0.00998
# [215]#011train-error:0.00998
# [216]#011train-error:0.00998
# [217]#011train-error:0.00998
# [218]#011train-error:0.00998
# [219]#011train-error:0.00998
# [220]#011train-error:0.00998
# [221]#011train-error:0.00998
# [222]#011train-error:0.00998
# [223]#011train-error:0.00998
# [224]#011train-error:0.00998
# [225]#011train-error:0.00998
# [226]#011train-error:0.00998
# [227]#011train-error:0.00998
# [228]#011train-error:0.00998
# [229]#011train-error:0.00998
# [230]#011train-error:0.00998
# [231]#011train-error:0.00998
# [232]#011train-error:0.00998
# [233]#011train-error:0.00998
# [234]#011train-error:0.00998
# [235]#011train-error:0.00998
# [236]#011train-error:0.00998
# [237]#011train-error:0.00998
# [238]#011train-error:0.00998
# [239]#011train-error:0.00998
# [240]#011train-error:0.00998
# [241]#011train-error:0.00832
# [242]#011train-error:0.00832
# [243]#011train-error:0.00998
# [244]#011train-error:0.00998
# [245]#011train-error:0.00998
# [246]#011train-error:0.00998
# [247]#011train-error:0.00998
# [248]#011train-error:0.00998
# [249]#011train-error:0.00998
# [250]#011train-error:0.00998
# [251]#011train-error:0.00998
# [252]#011train-error:0.00998
# [253]#011train-error:0.00998
# [254]#011train-error:0.00998
# [255]#011train-error:0.00998
# [256]#011train-error:0.00998
# [257]#011train-error:0.00832
# [258]#011train-error:0.00832
# [259]#011train-error:0.00832
# [260]#011train-error:0.00998
# [261]#011train-error:0.00832
# [262]#011train-error:0.00666
# [263]#011train-error:0.00666
# [264]#011train-error:0.00666
# [265]#011train-error:0.00666
# [266]#011train-error:0.00499
# [267]#011train-error:0.00666
# [268]#011train-error:0.00499
# [269]#011train-error:0.00666
# [270]#011train-error:0.00499
# [271]#011train-error:0.00666
# [272]#011train-error:0.00499
# [273]#011train-error:0.00499
# [274]#011train-error:0.00666
# [275]#011train-error:0.00499
# [276]#011train-error:0.00499
# [277]#011train-error:0.00666
# [278]#011train-error:0.00666
# [279]#011train-error:0.00666
# [280]#011train-error:0.00666
# [281]#011train-error:0.00499
# [282]#011train-error:0.00499
# [283]#011train-error:0.00499
# [284]#011train-error:0.00499
# [285]#011train-error:0.00499
# [286]#011train-error:0.00499
# [287]#011train-error:0.00499
# [288]#011train-error:0.00499
# [289]#011train-error:0.00499
# [290]#011train-error:0.00499
# [291]#011train-error:0.00499
# [292]#011train-error:0.00499
# [293]#011train-error:0.00499
# [294]#011train-error:0.00499
# [295]#011train-error:0.00499
# [296]#011train-error:0.00666
# [297]#011train-error:0.00499
# [298]#011train-error:0.00499
# [299]#011train-error:0.00666
# [300]#011train-error:0.00499
# [301]#011train-error:0.00499
# [302]#011train-error:0.00499
# [303]#011train-error:0.00499
# [304]#011train-error:0.00499
# [305]#011train-error:0.00499
# [306]#011train-error:0.00499
# [307]#011train-error:0.00499
# [308]#011train-error:0.00499
# [309]#011train-error:0.00499
# [310]#011train-error:0.00499
# [311]#011train-error:0.00499
# [312]#011train-error:0.00499
# [313]#011train-error:0.00499
# [314]#011train-error:0.00499
# [315]#011train-error:0.00499
# [316]#011train-error:0.00499
# [317]#011train-error:0.00499
# [318]#011train-error:0.00499
# [319]#011train-error:0.00499
# [320]#011train-error:0.00499
# [321]#011train-error:0.00499
# [322]#011train-error:0.00499
# [323]#011train-error:0.00499
# [324]#011train-error:0.00499
# [325]#011train-error:0.00499
# [326]#011train-error:0.00499
# [327]#011train-error:0.00499
# [328]#011train-error:0.00499
# [329]#011train-error:0.00499
# [330]#011train-error:0.00499
# [331]#011train-error:0.00499
# [332]#011train-error:0.00499
# [333]#011train-error:0.00499
# [334]#011train-error:0.00499
# [335]#011train-error:0.00499
# [336]#011train-error:0.00499
# [337]#011train-error:0.00499
# [338]#011train-error:0.00499
# [339]#011train-error:0.00499
# [340]#011train-error:0.00499
# [341]#011train-error:0.00499
# [342]#011train-error:0.00499
# [343]#011train-error:0.00499
# [344]#011train-error:0.00499
# [345]#011train-error:0.00499
# [346]#011train-error:0.00499
# [347]#011train-error:0.00499
# [348]#011train-error:0.00499
# [349]#011train-error:0.00499
# [350]#011train-error:0.00499
# [351]#011train-error:0.00499
# [352]#011train-error:0.00499
# [353]#011train-error:0.00499
# [354]#011train-error:0.00499
# [355]#011train-error:0.00499
# [356]#011train-error:0.00499
# [357]#011train-error:0.00499
# [358]#011train-error:0.00499
# [359]#011train-error:0.00499
# [360]#011train-error:0.00499
# [361]#011train-error:0.00499
# [362]#011train-error:0.00499
# [363]#011train-error:0.00499
# [364]#011train-error:0.00499
# [365]#011train-error:0.00499
# [366]#011train-error:0.00499
# [367]#011train-error:0.00499
# [368]#011train-error:0.00499
# [369]#011train-error:0.00499
# [370]#011train-error:0.00499
# [371]#011train-error:0.00499
# [372]#011train-error:0.00499
# [373]#011train-error:0.00499
# [374]#011train-error:0.00499
# [375]#011train-error:0.00499
# [376]#011train-error:0.00499
# [377]#011train-error:0.00499
# [378]#011train-error:0.00499
# [379]#011train-error:0.00499
# [380]#011train-error:0.00499
# [381]#011train-error:0.00499
# [382]#011train-error:0.00499
# [383]#011train-error:0.00499
# [384]#011train-error:0.00499
# [385]#011train-error:0.00499
# [386]#011train-error:0.00499
# [387]#011train-error:0.00499
# [388]#011train-error:0.00499
# [389]#011train-error:0.00499
# [390]#011train-error:0.00333
# [391]#011train-error:0.00333
# [392]#011train-error:0.00166
# [393]#011train-error:0.00166
# [394]#011train-error:0.00499
# [395]#011train-error:0.00333
# [396]#011train-error:0.00333
# [397]#011train-error:0.00166
# [398]#011train-error:0.00333
# [399]#011train-error:0.00333
# [400]#011train-error:0.00499
# [401]#011train-error:0.00499
# [402]#011train-error:0.00333
# [403]#011train-error:0.00333
# [404]#011train-error:0.00333
# [405]#011train-error:0.00333
# [406]#011train-error:0.00499
# [407]#011train-error:0.00166
# [408]#011train-error:0.00333
# [409]#011train-error:0.00499
# [410]#011train-error:0.00333
# [411]#011train-error:0.00499
# [412]#011train-error:0.00166
# [413]#011train-error:0.00166
# [414]#011train-error:0.00166
# [415]#011train-error:0.00166
# [416]#011train-error:0.00166
# [417]#011train-error:0.00166
# [418]#011train-error:0.00166
# [419]#011train-error:0.00166
# [420]#011train-error:0.00166
# [421]#011train-error:0.00166
# [422]#011train-error:0.00333
# [423]#011train-error:0.00333
# [424]#011train-error:0.00166
# [425]#011train-error:0.00166
# [426]#011train-error:0.00166
# [427]#011train-error:0.00166
# [428]#011train-error:0.00166
# [429]#011train-error:0.00166
# [430]#011train-error:0.00166
# [431]#011train-error:0.00166
# [432]#011train-error:0.00166
# [433]#011train-error:0.00166
# [434]#011train-error:0.00166
# [435]#011train-error:0.00333
# [436]#011train-error:0.00333
# [437]#011train-error:0.00333
# [438]#011train-error:0.00333
# [439]#011train-error:0.00333
# [440]#011train-error:0.00333
# [441]#011train-error:0.00333
# [442]#011train-error:0.00333
# [443]#011train-error:0.00166
# [444]#011train-error:0.00333
# [445]#011train-error:0.00166
# [446]#011train-error:0.00333
# [447]#011train-error:0.00333
# [448]#011train-error:0.00333
# [449]#011train-error:0.00333
# [450]#011train-error:0.00333
# [451]#011train-error:0.00333
# [452]#011train-error:0.00333
# [453]#011train-error:0.00166
# [454]#011train-error:0.00166
# [455]#011train-error:0.00166
# [456]#011train-error:0.00166
# [457]#011train-error:0.00166
# [458]#011train-error:0.00166
# [459]#011train-error:0.00166
# [460]#011train-error:0.00166
# [461]#011train-error:0.00166
# [462]#011train-error:0.00166
# [463]#011train-error:0.00166
# [464]#011train-error:0.00166
# [465]#011train-error:0.00166
# [466]#011train-error:0.00166
# [467]#011train-error:0.00166
# [468]#011train-error:0.00166
# [469]#011train-error:0.00166
# [470]#011train-error:0.00166
# [471]#011train-error:0.00166
# [472]#011train-error:0.00166
# [473]#011train-error:0.00166
# [474]#011train-error:0.00166
# [475]#011train-error:0.00166
# [476]#011train-error:0.00166
# [477]#011train-error:0.00166
# [478]#011train-error:0.00166
# [479]#011train-error:0.00166
# [480]#011train-error:0.00166
# [481]#011train-error:0.00166
# [482]#011train-error:0.00166
# [483]#011train-error:0.00166
# [484]#011train-error:0.00166
# [485]#011train-error:0.00166
# [486]#011train-error:0.00166
# [487]#011train-error:0.00166
# [488]#011train-error:0.00166
# [489]#011train-error:0.00166
# [490]#011train-error:0.00166
# [491]#011train-error:0.00166
# [492]#011train-error:0.00166
# [493]#011train-error:0.00166
# [494]#011train-error:0.00166
# [495]#011train-error:0.00166
# [496]#011train-error:0.00166
# [497]#011train-error:0.00166
# [498]#011train-error:0.00166
# [499]#011train-error:0.00166
#
# 2021-06-13 17:38:29 Uploading - Uploading generated training model
# 2021-06-13 17:38:29 Completed - Training job completed
# Training seconds: 78
# Billable seconds: 78
# CPU times: user 572 ms, sys: 104 ms, total: 676 ms
# Wall time: 4min 12s

# %%
import random
from string import ascii_uppercase

def generate_model_name():
    chars = random.choices(ascii_uppercase, k=5)
    output = 'model-' + ''.join(chars)
    return output

# %%
model_name = generate_model_name()
model_name
# Out:
# 'model-VWXTC'

# %%
model = estimator.create_model(name=model_name)

# %%
type(model)
# Out:
# sagemaker.model.Model

# %%
model.__dict__
# Out:
# {'model_data': 's3://sagemaker-us-east-1-581320662326/sagemaker-xgboost-2021-06-13-17-34-37-316/output/model.tar.gz',
#  'image_uri': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.2-1',
#  'role': 'arn:aws:iam::581320662326:role/SuperAdminRole',
#  'predictor_cls': <function sagemaker.estimator.Estimator.create_model.<locals>.predict_wrapper(endpoint, session)>,
#  'env': {},
#  'name': 'model-VWXTC',
#  '_base_name': None,
#  'vpc_config': None,
#  'sagemaker_session': <sagemaker.session.Session at 0x7ff430352310>,
#  'endpoint_name': None,
#  '_is_compiled_model': False,
#  '_compilation_job_name': None,
#  '_is_edge_packaged_model': False,
#  '_enable_network_isolation': False,
#  'model_kms_key': None,
#  'image_config': None}

# %%
container_def = model.prepare_container_def()
container_def
# Out:
# {'Image': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.2-1',
#  'Environment': {},
#  'ModelDataUrl': 's3://sagemaker-us-east-1-581320662326/sagemaker-xgboost-2021-06-13-17-34-37-316/output/model.tar.gz'}

# %%
session.create_model(
    model_name,
    role,
    container_def
)
# Out:
# 'model-VWXTC'

# %%
from sagemaker.clarify import SageMakerClarifyProcessor

processor = SageMakerClarifyProcessor(
    role=role,                                                  
    instance_count=1,                                                  
    instance_type='ml.m5.large',
    sagemaker_session=session
)

# %%
from sagemaker.clarify import DataConfig

data_config = DataConfig(
    s3_data_input_path=s3_training_data_path,
    s3_output_path=s3_output_path,
    label='approved',
    headers=training_data.columns.to_list(),
    dataset_type='text/csv'
)

data_config.__dict__
# Out:
# {'s3_data_input_path': 's3://sagemaker-cookbook-bucket/chapter07/input/training_data.csv',
#  's3_output_path': 's3://sagemaker-cookbook-bucket/chapter07/output',
#  's3_data_distribution_type': 'FullyReplicated',
#  's3_compression_type': 'None',
#  'label': 'approved',
#  'headers': ['approved',
#   'sex',
#   'math',
#   'science',
#   'technology',
#   'random1',
#   'random2'],
#  'features': None,
#  'analysis_config': {'dataset_type': 'text/csv',
#   'headers': ['approved',
#    'sex',
#    'math',
#    'science',
#    'technology',
#    'random1',
#    'random2'],
#   'label': 'approved'}}

# %%
from sagemaker.clarify import ModelConfig

model_config = ModelConfig(
    model_name=model_name,
    instance_type='ml.c5.xlarge',
    instance_count=1,
    accept_type='text/csv'
)

# %%
from sagemaker.clarify import ModelPredictedLabelConfig

predictions_config = ModelPredictedLabelConfig(
    probability_threshold=0.5
)

# %%
from sagemaker.clarify import BiasConfig

bias_config = BiasConfig(
    label_values_or_threshold=[1],              
    facet_name='sex',                             
)

# %%
# %%time

processor.run_post_training_bias(
    data_config=data_config, 
    data_bias_config=bias_config,
    methods=['DPPL', 'RD'],
    model_config=model_config,
    model_predicted_label_config=predictions_config
)
# Out:
# Job Name:  Clarify-Posttraining-Bias-2021-06-13-17-38-51-184
# Inputs:  [{'InputName': 'dataset', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-cookbook-bucket/chapter07/input/training_data.csv', 'LocalPath': '/opt/ml/processing/input/data', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}, {'InputName': 'analysis_config', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-cookbook-bucket/chapter07/output/analysis_config.json', 'LocalPath': '/opt/ml/processing/input/config', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}]
# Outputs:  [{'OutputName': 'analysis_result', 'AppManaged': False, 'S3Output': {'S3Uri': 's3://sagemaker-cookbook-bucket/chapter07/output', 'LocalPath': '/opt/ml/processing/output', 'S3UploadMode': 'EndOfJob'}}]
# ................................INFO:sagemaker-clarify-processing:Starting SageMaker Clarify Processing job
# INFO:analyzer.data_loading.data_loader_util:Analysis config path: /opt/ml/processing/input/config/analysis_config.json
# INFO:analyzer.data_loading.data_loader_util:Analysis result path: /opt/ml/processing/output
# INFO:analyzer.data_loading.data_loader_util:This host is algo-1.
# INFO:analyzer.data_loading.data_loader_util:This host is the leader.
# INFO:analyzer.data_loading.data_loader_util:Number of hosts in the cluster is 1.
# INFO:sagemaker-clarify-processing:Running Python / Pandas based analyzer.
# INFO:analyzer.data_loading.data_loader_util:Dataset uri: /opt/ml/processing/input/data
# INFO:analyzer.data_loading.data_loader_util:Dataset type: text/csv
# INFO:analyzer.predictor:Spinning up shadow endpoint
# INFO:sagemaker:Creating endpoint-config with name sagemaker-clarify-endpoint-config-1623606237-53f5
# INFO:analyzer.predictor:Creating endpoint sagemaker-clarify-endpoint-1623606237-93ea
# INFO:sagemaker-clarify-processing:======================================
# INFO:sagemaker-clarify-processing:Calculating post-training bias metrics
# INFO:sagemaker-clarify-processing:======================================
# INFO:sagemaker-clarify-processing:Getting predictions from the endpoint
# INFO:analyzer.predictor:Checking endpoint status
# INFO:analyzer.predictor:Endpoint is in service after 421 seconds
# INFO:analyzer.predictor:Prediction batch size is initialized with 370085
# INFO:analyzer.prediction_util:We assume a prediction above 0.500 indicates 1 and below or equal indicates 0.
# INFO:smclarify.bias.metrics.common:data uniqueness fraction: 0.0033333333333333335
# INFO:smclarify.bias.metrics.common:data uniqueness fraction: 0.0033333333333333335
# INFO:smclarify.bias.metrics.common:data uniqueness fraction: 0.0033333333333333335
# INFO:smclarify.bias.metrics.common:data uniqueness fraction: 0.0033333333333333335
# INFO:smclarify.bias.metrics.common:data uniqueness fraction: 0.0033333333333333335
# INFO:analyzer.predictor:Stop using endpoint: sagemaker-clarify-endpoint-1623606237-93ea
# INFO:sagemaker:Deleting endpoint configuration with name: sagemaker-clarify-endpoint-config-1623606237-53f5
# INFO:sagemaker:Deleting endpoint with name: sagemaker-clarify-endpoint-1623606237-93ea
# INFO:analyzer.predictor:Model endpoint delivered 6.19053 requests per second and a total of 1 requests over 0 seconds
# INFO:analyzer.predictor:Delivered 1 predict calls with a total of 600 examples.
# INFO:analyzer.predictor:Stop using endpoint: None
# INFO:analyzer.predictor:Delivered 1 predict calls with a total of 600 examples.
# INFO:sagemaker-clarify-processing:======================================
# INFO:sagemaker-clarify-processing:Calculating bias statistics for report
# INFO:sagemaker-clarify-processing:======================================
# INFO:smclarify.bias.metrics.common:data uniqueness fraction: 0.0033333333333333335
# INFO:smclarify.bias.metrics.common:data uniqueness fraction: 0.0033333333333333335
# INFO:smclarify.bias.metrics.common:data uniqueness fraction: 0.0033333333333333335
# INFO:smclarify.bias.metrics.common:data uniqueness fraction: 0.0033333333333333335
# INFO:smclarify.bias.metrics.common:data uniqueness fraction: 0.0033333333333333335
# INFO:analyzer.report:jupyter nbconvert --to html --output /opt/ml/processing/output/report.html /opt/ml/processing/output/report.ipynb --template sagemaker-xai
# [NbConvertApp] Converting notebook /opt/ml/processing/output/report.ipynb to html
# [NbConvertApp] Writing 313657 bytes to /opt/ml/processing/output/report.html
# INFO:analyzer.report:HTML report '/opt/ml/processing/output/report.html' generated successfully.
# INFO:analyzer.report:wkhtmltopdf -q /opt/ml/processing/output/report.html /opt/ml/processing/output/report.pdf
# INFO:analyzer.report:PDF report '/opt/ml/processing/output/report.pdf' generated successfully.
# INFO:sagemaker-clarify-processing:Collected analyses:
# {
#     "version": "1.0",
#     "post_training_bias_metrics": {
#         "label": "approved",
#         "facets": {
#             "sex": [
#                 {
#                     "value_or_threshold": "1",
#                     "metrics": [
#                         {
#                             "name": "DPPL",
#                             "description": "Difference in Positive Proportions in Predicted Labels (DPPL)",
#                             "value": -0.33541395157418197
#                         },
#                         {
#                             "name": "RD",
#                             "description": "Recall Difference (RD)",
#                             "value": 0.0
#                         }
#                     ]
#                 },
#                 {
#                     "value_or_threshold": "0",
#                     "metrics": [
#                         {
#                             "name": "DPPL",
#                             "description": "Difference in Positive Proportions in Predicted Labels (DPPL)",
#                             "value": 0.33541395157418197
#                         },
#                         {
#                             "name": "RD",
#                             "description": "Recall Difference (RD)",
#                             "value": 0.0
#                         }
#                     ]
#                 }
#             ]
#         },
#         "label_value_or_threshold": "1"
#     }
# }
# INFO:analyzer.system_util:exit_message: Completed: SageMaker XAI Analyzer ran successfully
# -------!
#
# CPU times: user 1.44 s, sys: 92.2 ms, total: 1.53 s
# Wall time: 12min 59s

# %%
output = processor.latest_job.outputs[0]
output_destination = output.destination
output_destination
# Out:
# 's3://sagemaker-cookbook-bucket/chapter07/output'

# %%
# !aws s3 cp {output_destination}/ tmp/ --recursive
# Out:
# download: s3://sagemaker-cookbook-bucket/chapter07/output/analysis_config.json to tmp/analysis_config.json
# download: s3://sagemaker-cookbook-bucket/chapter07/output/analysis.json to tmp/analysis.json
# download: s3://sagemaker-cookbook-bucket/chapter07/output/explanations_shap/baseline.csv to tmp/explanations_shap/baseline.csv
# download: s3://sagemaker-cookbook-bucket/chapter07/output/report.pdf to tmp/report.pdf
# download: s3://sagemaker-cookbook-bucket/chapter07/output/report.ipynb to tmp/report.ipynb
# download: s3://sagemaker-cookbook-bucket/chapter07/output/report.html to tmp/report.html
# download: s3://sagemaker-cookbook-bucket/chapter07/output/explanations_shap/out.csv to tmp/explanations_shap/out.csv

# %%
# !ls -lahF tmp/
# Out:
# total 936K
# drwxr-xr-x 4 root root 6.0K Jun 13 17:51 ./
# drwxr-xr-x 6 root root 6.0K Jun 13 17:50 ../
# drwxr-xr-x 2 root root 6.0K May 29 23:03 .ipynb_checkpoints/
# -rw-r--r-- 1 root root 1.4K Jun 13 17:51 analysis.json
# -rw-r--r-- 1 root root  492 Jun 13 17:38 analysis_config.json
# -rw-r--r-- 1 root root 139K May 24 17:15 baseline.csv
# -rw-r--r-- 1 root root 133K May 24 17:28 baseline_no_label.csv
# -rw-r--r-- 1 root root 1.1K May 24 20:29 constraints.json
# drwxr-xr-x 2 root root 6.0K Jun 13 17:51 explanations_shap/
# -rw-r--r-- 1 root root 307K Jun 13 17:51 report.html
# -rw-r--r-- 1 root root  41K Jun 13 17:51 report.ipynb
# -rw-r--r-- 1 root root  58K Jun 13 17:51 report.pdf
# -rw-r--r-- 1 root root  407 May 24 15:11 sample.jsonl
# -rw-r--r-- 1 root root 122K May 24 20:29 statistics.json
# -rw-r--r-- 1 root root 3.8K Jun 13 17:23 test_data.csv
# -rw-r--r-- 1 root root 3.8K Jun 13 17:23 test_data_no_header.csv
# -rw-r--r-- 1 root root  45K May 30 09:03 test_features.csv
# -rw-r--r-- 1 root root  12K Jun 13 17:23 training_data.csv
# -rw-r--r-- 1 root root  12K Jun 13 17:23 training_data_no_header.csv
# -rw-r--r-- 1 root root 3.8K Jun 13 17:23 validation_data.csv
# -rw-r--r-- 1 root root 3.8K Jun 13 17:23 validation_data_no_header.csv
# -rw-r--r-- 1 root root  529 May 24 21:15 violations.json

# %%
# !cat tmp/analysis.json
# Out:
# {
#     "version": "1.0",
#     "post_training_bias_metrics": {
#         "label": "approved",
#         "facets": {
#             "sex": [
#                 {
#                     "value_or_threshold": "1",
#                     "metrics": [
#                         {
#                             "name": "DPPL",
#                             "description": "Difference in Positive Proportions in Predicted Labels (DPPL)",
#                             "value": -0.33541395157418197
#                         },
#                         {
#                             "name": "RD",
#                             "description": "Recall Difference (RD)",
#                             "value": 0.0
#                         }
#                     ]
#                 },
#                 {
#                     "value_or_threshold": "0",
#                     "metrics": [
#                         {
#                             "name": "DPPL",
#                             "description": "Difference in Positive Proportions in Predicted Labels (DPPL)",
#                             "value": 0.33541395157418197
#                         },
#                         {
#                             "name": "RD",
#                             "description": "Recall Difference (RD)",
#                             "value": 0.0
#                         }
#                     ]
#                 }
#             ]
#         },
#         "label_value_or_threshold": "1"
#     }
# }

# %%
# %store model_name
model_name
# Out:
# Stored 'model_name' (str)
# 'model-VWXTC'
