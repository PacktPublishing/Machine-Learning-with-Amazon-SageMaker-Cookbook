# %%
import time

from smexperiments.experiment import Experiment
from smexperiments.trial import Trial
from smexperiments.trial_component import TrialComponent
from smexperiments.tracker import Tracker

# %%
def delete_trial(trial, dry_run=False):
    for trial_component_summary in trial.list_trial_components():
        trial_component_name = trial_component_summary.trial_component_name
        trial_component = TrialComponent.load(trial_component_name=trial_component_name)

        if not dry_run:
            print(f"REMOVING TRIAL COMPONENT FROM TRIAL: {trial_component_name}")
            try:
                trial.remove_trial_component(trial_component)
                print(f"SUCCESSFULLY REMOVED TRIAL COMPONENT")
            except:
                print(f"FAILED TO DELETE TRIAL COMPONENT")
                pass
            
            print(f"DELETING TRIAL COMPONENT: {trial_component_name}")
            try:
                trial_component.delete(force_disassociate=True)
                print(f"SUCCESSFULLY DELETED: {trial_component_name}")
            except:
                print(f"FAILED TO DELETE: {trial_component_name}")
                continue
        else:
            print(f"[DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: {trial_component_name}")
            print(f"[DRY RUN] DELETING TRIAL COMPONENT: {trial_component_name}")    

        time.sleep(1)

    if not dry_run:
        print(f"DELETING TRIAL: {trial.trial_name}")
        try:
            trial.delete()
            print(f"SUCCESSFULLY DELETED: {trial.trial_name}")
        except:
            print(f"FAILED TO DELETE: {trial.trial_name}")
    else:
        print(f"[DRY RUN] DELETING TRIAL: {trial.trial_name}")

# %%
def delete_experiment(experiment, dry_run=False):
    print(f"CLEANING UP EXPERIMENT: {experiment.display_name}")
    
    for trial_summary in experiment.list_trials():
        trial_name = trial_summary.trial_name
        print(f"CLEANING UP TRIAL: {trial_name}")
        trial = Trial.load(trial_name=trial_name)
        
        delete_trial(trial, dry_run=dry_run)
            
        experiment_name = experiment.experiment_name
        
    if not dry_run:
        print(f"DELETING EXPERIMENT: {experiment.experiment_name}")
        experiment.delete_all(action="--force")
    else:
        print(f"[DRY RUN] DELETING EXPERIMENT: {experiment.experiment_name}")

# %%
for experiment_summary in Experiment.list():
    experiment = Experiment.load(experiment_summary.experiment_name)
    delete_experiment(experiment=experiment, dry_run=True)
# Out:
# CLEANING UP EXPERIMENT: experiment-CIGZKZVFZO
# CLEANING UP TRIAL: trial-DLLKOGQBPW
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: job-DLLKOGQBPW-aws-training-job
# [DRY RUN] DELETING TRIAL COMPONENT: job-DLLKOGQBPW-aws-training-job
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153604-yjbk
# [DRY RUN] DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153604-yjbk
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153256-bnxj
# [DRY RUN] DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153256-bnxj
# [DRY RUN] DELETING TRIAL: trial-DLLKOGQBPW
# CLEANING UP TRIAL: trial-DHMUPWSORF
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: job-DHMUPWSORF-aws-training-job
# [DRY RUN] DELETING TRIAL COMPONENT: job-DHMUPWSORF-aws-training-job
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153602-dqtv
# [DRY RUN] DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153602-dqtv
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153256-bnxj
# [DRY RUN] DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153256-bnxj
# [DRY RUN] DELETING TRIAL: trial-DHMUPWSORF
# CLEANING UP TRIAL: trial-HLMHVSHJLD
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: job-HLMHVSHJLD-aws-training-job
# [DRY RUN] DELETING TRIAL COMPONENT: job-HLMHVSHJLD-aws-training-job
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153559-ctqi
# [DRY RUN] DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153559-ctqi
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153256-bnxj
# [DRY RUN] DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153256-bnxj
# [DRY RUN] DELETING TRIAL: trial-HLMHVSHJLD
# CLEANING UP TRIAL: trial-IGYOEWLLKC
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: job-IGYOEWLLKC-aws-training-job
# [DRY RUN] DELETING TRIAL COMPONENT: job-IGYOEWLLKC-aws-training-job
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153557-qdyw
# [DRY RUN] DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153557-qdyw
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153256-bnxj
# [DRY RUN] DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153256-bnxj
# [DRY RUN] DELETING TRIAL: trial-IGYOEWLLKC
# CLEANING UP TRIAL: trial-EEIGKCWSSO
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: job-EEIGKCWSSO-aws-training-job
# [DRY RUN] DELETING TRIAL COMPONENT: job-EEIGKCWSSO-aws-training-job
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153554-seca
# [DRY RUN] DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153554-seca
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153256-bnxj
# [DRY RUN] DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153256-bnxj
# [DRY RUN] DELETING TRIAL: trial-EEIGKCWSSO
# CLEANING UP TRIAL: trial-WLMUZICGAH
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: job-WLMUZICGAH-aws-training-job
# [DRY RUN] DELETING TRIAL COMPONENT: job-WLMUZICGAH-aws-training-job
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153551-mlad
# [DRY RUN] DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153551-mlad
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153256-bnxj
# [DRY RUN] DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153256-bnxj
# [DRY RUN] DELETING TRIAL: trial-WLMUZICGAH
# CLEANING UP TRIAL: trial-SVKXQJNJXR
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: job-SVKXQJNJXR-aws-training-job
# [DRY RUN] DELETING TRIAL COMPONENT: job-SVKXQJNJXR-aws-training-job
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153549-yvek
# [DRY RUN] DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153549-yvek
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153256-bnxj
# [DRY RUN] DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153256-bnxj
# [DRY RUN] DELETING TRIAL: trial-SVKXQJNJXR
# CLEANING UP TRIAL: trial-UUMPHCNNKS
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: job-UUMPHCNNKS-aws-training-job
# [DRY RUN] DELETING TRIAL COMPONENT: job-UUMPHCNNKS-aws-training-job
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153546-yzji
# [DRY RUN] DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153546-yzji
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153256-bnxj
# [DRY RUN] DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153256-bnxj
# [DRY RUN] DELETING TRIAL: trial-UUMPHCNNKS
# CLEANING UP TRIAL: trial-HEJMOENWXW
# [DRY RUN] DELETING TRIAL: trial-HEJMOENWXW
# CLEANING UP TRIAL: trial-ZQRUWYEXTU
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: job-ZQRUWYEXTU-aws-training-job
# [DRY RUN] DELETING TRIAL COMPONENT: job-ZQRUWYEXTU-aws-training-job
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153401-aebp
# [DRY RUN] DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153401-aebp
# [DRY RUN] REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153256-bnxj
# [DRY RUN] DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153256-bnxj
# [DRY RUN] DELETING TRIAL: trial-ZQRUWYEXTU
# [DRY RUN] DELETING EXPERIMENT: experiment-CIGZKZVFZO

# %%
for experiment_summary in Experiment.list():
    experiment = Experiment.load(experiment_summary.experiment_name)
    delete_experiment(experiment=experiment, dry_run=False)
# Out:
# CLEANING UP EXPERIMENT: experiment-CIGZKZVFZO
# CLEANING UP TRIAL: trial-DLLKOGQBPW
# REMOVING TRIAL COMPONENT FROM TRIAL: job-DLLKOGQBPW-aws-training-job
# SUCCESSFULLY REMOVED TRIAL COMPONENT
# DELETING TRIAL COMPONENT: job-DLLKOGQBPW-aws-training-job
# SUCCESSFULLY DELETED: job-DLLKOGQBPW-aws-training-job
# REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153604-yjbk
# SUCCESSFULLY REMOVED TRIAL COMPONENT
# DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153604-yjbk
# SUCCESSFULLY DELETED: TrialComponent-2021-04-23-153604-yjbk
# REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153256-bnxj
# SUCCESSFULLY REMOVED TRIAL COMPONENT
# DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153256-bnxj
# SUCCESSFULLY DELETED: TrialComponent-2021-04-23-153256-bnxj
# DELETING TRIAL: trial-DLLKOGQBPW
# SUCCESSFULLY DELETED: trial-DLLKOGQBPW
# CLEANING UP TRIAL: trial-DHMUPWSORF
# REMOVING TRIAL COMPONENT FROM TRIAL: job-DHMUPWSORF-aws-training-job
# SUCCESSFULLY REMOVED TRIAL COMPONENT
# DELETING TRIAL COMPONENT: job-DHMUPWSORF-aws-training-job
# SUCCESSFULLY DELETED: job-DHMUPWSORF-aws-training-job
# REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153602-dqtv
# SUCCESSFULLY REMOVED TRIAL COMPONENT
# DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153602-dqtv
# SUCCESSFULLY DELETED: TrialComponent-2021-04-23-153602-dqtv
# DELETING TRIAL: trial-DHMUPWSORF
# SUCCESSFULLY DELETED: trial-DHMUPWSORF
# CLEANING UP TRIAL: trial-HLMHVSHJLD
# REMOVING TRIAL COMPONENT FROM TRIAL: job-HLMHVSHJLD-aws-training-job
# SUCCESSFULLY REMOVED TRIAL COMPONENT
# DELETING TRIAL COMPONENT: job-HLMHVSHJLD-aws-training-job
# SUCCESSFULLY DELETED: job-HLMHVSHJLD-aws-training-job
# REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153559-ctqi
# SUCCESSFULLY REMOVED TRIAL COMPONENT
# DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153559-ctqi
# SUCCESSFULLY DELETED: TrialComponent-2021-04-23-153559-ctqi
# DELETING TRIAL: trial-HLMHVSHJLD
# SUCCESSFULLY DELETED: trial-HLMHVSHJLD
# CLEANING UP TRIAL: trial-IGYOEWLLKC
# REMOVING TRIAL COMPONENT FROM TRIAL: job-IGYOEWLLKC-aws-training-job
# SUCCESSFULLY REMOVED TRIAL COMPONENT
# DELETING TRIAL COMPONENT: job-IGYOEWLLKC-aws-training-job
# SUCCESSFULLY DELETED: job-IGYOEWLLKC-aws-training-job
# REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153557-qdyw
# SUCCESSFULLY REMOVED TRIAL COMPONENT
# DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153557-qdyw
# SUCCESSFULLY DELETED: TrialComponent-2021-04-23-153557-qdyw
# DELETING TRIAL: trial-IGYOEWLLKC
# SUCCESSFULLY DELETED: trial-IGYOEWLLKC
# CLEANING UP TRIAL: trial-EEIGKCWSSO
# REMOVING TRIAL COMPONENT FROM TRIAL: job-EEIGKCWSSO-aws-training-job
# SUCCESSFULLY REMOVED TRIAL COMPONENT
# DELETING TRIAL COMPONENT: job-EEIGKCWSSO-aws-training-job
# SUCCESSFULLY DELETED: job-EEIGKCWSSO-aws-training-job
# REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153554-seca
# SUCCESSFULLY REMOVED TRIAL COMPONENT
# DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153554-seca
# SUCCESSFULLY DELETED: TrialComponent-2021-04-23-153554-seca
# DELETING TRIAL: trial-EEIGKCWSSO
# SUCCESSFULLY DELETED: trial-EEIGKCWSSO
# CLEANING UP TRIAL: trial-WLMUZICGAH
# REMOVING TRIAL COMPONENT FROM TRIAL: job-WLMUZICGAH-aws-training-job
# SUCCESSFULLY REMOVED TRIAL COMPONENT
# DELETING TRIAL COMPONENT: job-WLMUZICGAH-aws-training-job
# SUCCESSFULLY DELETED: job-WLMUZICGAH-aws-training-job
# REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153551-mlad
# SUCCESSFULLY REMOVED TRIAL COMPONENT
# DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153551-mlad
# SUCCESSFULLY DELETED: TrialComponent-2021-04-23-153551-mlad
# DELETING TRIAL: trial-WLMUZICGAH
# SUCCESSFULLY DELETED: trial-WLMUZICGAH
# CLEANING UP TRIAL: trial-SVKXQJNJXR
# REMOVING TRIAL COMPONENT FROM TRIAL: job-SVKXQJNJXR-aws-training-job
# SUCCESSFULLY REMOVED TRIAL COMPONENT
# DELETING TRIAL COMPONENT: job-SVKXQJNJXR-aws-training-job
# SUCCESSFULLY DELETED: job-SVKXQJNJXR-aws-training-job
# REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153549-yvek
# SUCCESSFULLY REMOVED TRIAL COMPONENT
# DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153549-yvek
# SUCCESSFULLY DELETED: TrialComponent-2021-04-23-153549-yvek
# DELETING TRIAL: trial-SVKXQJNJXR
# SUCCESSFULLY DELETED: trial-SVKXQJNJXR
# CLEANING UP TRIAL: trial-UUMPHCNNKS
# REMOVING TRIAL COMPONENT FROM TRIAL: job-UUMPHCNNKS-aws-training-job
# SUCCESSFULLY REMOVED TRIAL COMPONENT
# DELETING TRIAL COMPONENT: job-UUMPHCNNKS-aws-training-job
# SUCCESSFULLY DELETED: job-UUMPHCNNKS-aws-training-job
# REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153546-yzji
# SUCCESSFULLY REMOVED TRIAL COMPONENT
# DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153546-yzji
# SUCCESSFULLY DELETED: TrialComponent-2021-04-23-153546-yzji
# DELETING TRIAL: trial-UUMPHCNNKS
# SUCCESSFULLY DELETED: trial-UUMPHCNNKS
# CLEANING UP TRIAL: trial-HEJMOENWXW
# DELETING TRIAL: trial-HEJMOENWXW
# SUCCESSFULLY DELETED: trial-HEJMOENWXW
# CLEANING UP TRIAL: trial-ZQRUWYEXTU
# REMOVING TRIAL COMPONENT FROM TRIAL: job-ZQRUWYEXTU-aws-training-job
# SUCCESSFULLY REMOVED TRIAL COMPONENT
# DELETING TRIAL COMPONENT: job-ZQRUWYEXTU-aws-training-job
# SUCCESSFULLY DELETED: job-ZQRUWYEXTU-aws-training-job
# REMOVING TRIAL COMPONENT FROM TRIAL: TrialComponent-2021-04-23-153401-aebp
# SUCCESSFULLY REMOVED TRIAL COMPONENT
# DELETING TRIAL COMPONENT: TrialComponent-2021-04-23-153401-aebp
# SUCCESSFULLY DELETED: TrialComponent-2021-04-23-153401-aebp
# DELETING TRIAL: trial-ZQRUWYEXTU
# SUCCESSFULLY DELETED: trial-ZQRUWYEXTU
# DELETING EXPERIMENT: experiment-CIGZKZVFZO

# %%
for experiment_summary in Experiment.list():
    experiment = Experiment.load(experiment_summary.experiment_name)
    print(f"Forcefully deleting {experiment.experiment_name}")
    experiment.delete_all(action="--force")
