# %%
library('reticulate')
boto3 <- import('boto3')
athena <- boto3$client('athena', region_name='us-east-1')

# %%
query <- "SELECT label, value FROM cookbook_athena_db.athena_table;"
database <- "cookbook_athena_db"
results_bucket <- "s3://cookbook-athena-results"

# %%
execute_athena_query <- function(query, database, results_bucket) {
    response <- athena$start_query_execution(
        QueryString = query,
        QueryExecutionContext = dict(Database=database),
        ResultConfiguration = dict(OutputLocation=results_bucket)
    )    
    
    return(response$QueryExecutionId)
}

# %%
get_output_path <- function(execution_id) {
    query_details <- athena$get_query_execution(
        QueryExecutionId = execution_id
    )
    
    execution <- query_details$QueryExecution
    configuration <- execution$ResultConfiguration
    return(configuration$OutputLocation)
}

# %%
cmd <- function(bash_command) {
    print(bash_command)
    output <- system(bash_command, intern=TRUE)
    last_line = ""
    
    for (line in output) { 
        cat(line)
        cat("\n")
        last_line = line 
    }
    
    return(last_line) 
}

# %%
cmd("mkdir -p tmp")
# Out:
# [1] "mkdir -p tmp"
# [1] ""

# %%
execution_id <- execute_athena_query(query, database, results_bucket)
output_path <- get_output_path(execution_id)
output_path
# Out:
# [1] "s3://cookbook-athena-results/987d6fbe-6773-4279-a904-a351d070599b.csv"

# %%
command <- paste("aws s3 cp", output_path, "tmp/output.csv")

cmd(command)
# Out:
# [1] "aws s3 cp s3://cookbook-athena-results/987d6fbe-6773-4279-a904-a351d070599b.csv tmp/output.csv"
# download: s3://cookbook-athena-results/987d6fbe-6773-4279-a904-a351d070599b.csv to tmp/output.csv
# [1] "Completed 16.8 KiB/16.8 KiB (359.1 KiB/s) with 1 file(s) remaining\rdownload: s3://cookbook-athena-results/987d6fbe-6773-4279-a904-a351d070599b.csv to tmp/output.csv"

# %%
df <- read.csv("tmp/output.csv", header=TRUE)
df
# Out:
#      label      value
# 1    BVWIGECENF  2
# 2    EMELOEGMJV  1
# 3    RJIVHCZUBL  5
# 4    WVLWTZZGGN  8
# 5    YXFAVHXUBY  3
# 6    ZMLZMGCYGG  4
# 7    XJPTWNPRWU  2
# 8    YQEATBSHCI  1
# 9    XRRNFFLGOG  1
# 10   GLWYJCTFYE 10
# 11   MVWFSCPCUG  5
# 12   RGAWZTVXUQ  2
# 13   SPVYLNZUZQ  0
# 14   BHWXOAIMPN  8
# 15   XSUPDGFZGL  6
# 16   NOSYYZHAMI  8
# 17   EPCBUCHKUI  2
# 18   LDYBRWLXVK  9
# 19   HOFYJZHXNT  8
# 20   SUIKHOPINC  5
# 21   BEHYVGAHPK  7
# 22   LFIDMGCZVZ  7
# 23   TWQNHWXFHX  3
# 24   RRBZBPZEOW  3
# 25   BBEOAEHGVD  6
# 26   PAFDQKAHUA  2
# 27   MPXOXPDBBP  5
# 28   JRRSCOAYXJ  8
# 29   TYCKZHCMVL  4
# 30   GJVVKGTQJD  0
# ⋮    ⋮          ⋮
# 971  DWJBFDNNEZ  0
# 972  XVNZDBEGBM  2
# 973  OBANPNDMIK  5
# 974  MFPQNEOADK 10
# 975  YFFRUHVFUO  1
# 976  RGXZLDKKEQ  4
# 977  CMMWAKOZJE  8
# 978  UAEQRYVJRS  7
# 979  XEGRMPTEBY  7
# 980  ZGJTTJLVUK  2
# 981  SLBIMZTRFB  1
# 982  QAGKISKJRX  7
# 983  WALEGCVQCE  4
# 984  STXTWAEXUX  0
# 985  WVCZSJBPOE  3
# 986  ZQHKFCRYYD 77
# 987  AECUYQSMLR 10
# 988  ELXGVOWKXT  4
# 989  CRPOVJHNVO  1
# 990  OOULZBZSJW  8
# 991  RZSNUJNBTL  6
# 992  IFLDNUZKZG  4
# 993  SPLQISZBPS 10
# 994  ZLCKPKPGXK  5
# 995  MCGZGWQQWT  0
# 996  RSZQYGUYRB  8
# 997  AIKCHGSLVZ  2
# 998  DQWCRCVMUV  5
# 999  TKNGBXMAJQ  9
# 1000 TNXATCEQOT  2

# %%
query <- "
USING EXTERNAL FUNCTION detect_anomaly(value INT)
    RETURNS DOUBLE
    SAGEMAKER 'sagemaker-cookbook-rcf'
SELECT label, value, detect_anomaly(value) AS anomaly_score
    FROM cookbook_athena_db.athena_table"

# %%
execution_id <- execute_athena_query(query, database, results_bucket)
output_path <- get_output_path(execution_id)
output_path
# Out:
# [1] "s3://cookbook-athena-results/303e123b-2e39-41d2-999b-6420dabf3b03.csv"

# %%
command <- paste("aws s3 cp", output_path, "tmp/output.csv")
cmd(command)
# Out:
# [1] "aws s3 cp s3://cookbook-athena-results/303e123b-2e39-41d2-999b-6420dabf3b03.csv tmp/output.csv"
# download: s3://cookbook-athena-results/303e123b-2e39-41d2-999b-6420dabf3b03.csv to tmp/output.csv
# [1] "Completed 37.0 KiB/37.0 KiB (728.3 KiB/s) with 1 file(s) remaining\rdownload: s3://cookbook-athena-results/303e123b-2e39-41d2-999b-6420dabf3b03.csv to tmp/output.csv"

# %%
df <- read.csv("tmp/output.csv", header=TRUE)
df
# Out:
#      label      value anomaly_score
# 1    SIRTDXCEZH  3    0.9313710
# 2    UARRYGLNRB  4    0.8485596
# 3    ORFPUJWEFC 10    1.3119031
# 4    XUGMJRDURG 73    2.5832871
# 5    EFKZBCPNXH  6    0.8280757
# 6    LQEHDUVUUA  5    0.8484080
# 7    ZZZAPLVJFJ  3    0.9313710
# 8    DHZIQWAGQT  1    1.2045547
# 9    SBCPVTAWNZ  7    0.8708918
# 10   GJOCDYHYWB  6    0.8280757
# 11   EBPLBPRVNL  7    0.8708918
# 12   XGBTPICJXB  3    0.9313710
# 13   LLZTRLHDPL 70    2.5282072
# 14   TITQTWOEZV  0    1.4155134
# 15   KDAFWKEGAK  8    0.9353107
# 16   SCASAUTWMJ  0    1.4155134
# 17   OWKEAXSPHL  7    0.8708918
# 18   FKYFVHEPMH 78    2.5743458
# 19   BPOHSZAVOS  3    0.9313710
# 20   XQADOXMNJI 10    1.3119031
# 21   CKVJEZWBUN 76    2.6036155
# 22   VRQKFFRXEG  5    0.8484080
# 23   JIPSJUGZZP  8    0.9353107
# 24   USFZRORWHS  8    0.9353107
# 25   QHXTGYIZNW  5    0.8484080
# 26   FFOAWOWXQY 80    2.6370322
# 27   ENROUBDANN  4    0.8485596
# 28   OYOHNOPISD  5    0.8484080
# 29   DXOCDJOVUQ  9    1.0845330
# 30   UWEDYBJOME 10    1.3119031
# ⋮    ⋮          ⋮     ⋮
# 971  EMELOEGMJV  1    1.2045547
# 972  PFHVTXYFZM  8    0.9353107
# 973  NCIIDSAWLC  3    0.9313710
# 974  WZSHKPNRIX  3    0.9313710
# 975  QYKRMFAEKR  4    0.8485596
# 976  FESCRWPZEX  0    1.4155134
# 977  DGZMNWGWMV  9    1.0845330
# 978  WLVBQYZVFO  4    0.8485596
# 979  VOVSUNKFQK  5    0.8484080
# 980  KXSQOTZJXC  1    1.2045547
# 981  RZKKJDAENQ  4    0.8485596
# 982  GMHYIUWGKY  5    0.8484080
# 983  EOEHRHJTMI  5    0.8484080
# 984  PZJQMPOOYJ 71    2.5448792
# 985  ODGZRWQHNE  3    0.9313710
# 986  UPMZLYWUYW 74    2.6008418
# 987  CBPORYAJNP  6    0.8280757
# 988  WEUTILEHOM  7    0.8708918
# 989  YUTDBHLIBB  4    0.8485596
# 990  PXSAQROMQT  1    1.2045547
# 991  MBBPXELHEE  4    0.8485596
# 992  FYWEHIPKXV  5    0.8484080
# 993  KBVNJYOHAI  4    0.8485596
# 994  RQMAPMOCLZ  6    0.8280757
# 995  ERINTEMHAL 10    1.3119031
# 996  ESFTKGNZSL 10    1.3119031
# 997  ZGJTTJLVUK  2    0.9552411
# 998  XECZRFJSRC  5    0.8484080
# 999  RMEMMPCFCZ  9    1.0845330
# 1000 XEVYTZVKOI  2    0.9552411

# %%
subset(df, anomaly_score > 2)
# Out:
#     label      value anomaly_score
# 4   XUGMJRDURG 73    2.583287
# 13  LLZTRLHDPL 70    2.528207
# 18  FKYFVHEPMH 78    2.574346
# 21  CKVJEZWBUN 76    2.603616
# 26  FFOAWOWXQY 80    2.637032
# 36  HKTZQNIVNN 72    2.584881
# 61  TEEONPEITR 74    2.600842
# 67  DBRHTMQCUX 71    2.544879
# 76  HOSFZMJSBN 77    2.610782
# 106 WUYBRZQEXF 76    2.603616
# 154 KTDJDZJKHH 73    2.583287
# 191 VOENRCHQHR 75    2.543666
# 204 PULVMLWYXX 78    2.574346
# 240 FWXUMBFLYC 71    2.544879
# 246 GVORMCSETL 71    2.544879
# 258 SRJQRLTIFQ 78    2.574346
# 280 DMOFTOFXYF 77    2.610782
# 297 ZQHKFCRYYD 77    2.610782
# 337 LTBDZXYYZB 78    2.574346
# 373 AZWEFYLSPI 73    2.583287
# 401 GCTKAMCGOS 73    2.583287
# 419 MKOVMFRUVX 80    2.637032
# 449 DNZUJOITEJ 76    2.603616
# 492 HVZXNYNXGP 77    2.610782
# 498 LIQFNWSIEG 76    2.603616
# 501 LCXSBVHWUG 74    2.600842
# 502 QZQBUOHHPZ 79    2.566899
# 507 WMFNGXCIPD 72    2.584881
# 539 DYXSXNXGNV 80    2.637032
# 569 YMGMIIIDQC 78    2.574346
# 581 IKBAFKPMHD 72    2.584881
# 591 PDIKBRRQMC 77    2.610782
# 605 FSXQZEEISH 76    2.603616
# 627 YTXQMRKPTR 80    2.637032
# 659 EIXGNSBGQE 80    2.637032
# 700 JCDFTSRYSY 72    2.584881
# 706 YUCFPVMCPZ 76    2.603616
# 714 HYTKRSCRLA 80    2.637032
# 717 BZTNBFXSUR 74    2.600842
# 746 KVYITFNRIU 72    2.584881
# 795 ZCTLWGELDF 74    2.600842
# 836 ARPWFJOWOP 76    2.603616
# 846 MWYPFYEVTT 75    2.543666
# 870 ICNTFUNPJC 74    2.600842
# 940 ATDDEJHMCY 74    2.600842
# 984 PZJQMPOOYJ 71    2.544879
# 986 UPMZLYWUYW 74    2.600842
