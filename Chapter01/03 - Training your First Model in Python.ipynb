# %% [markdown]
# ## Training your First Model in Python
#
# - **Kernel**: `conda_python3`
# - **SageMaker Python SDK Version**: `2.X`

# %%
# %store -r df_all_data

# %%
from sklearn.model_selection import train_test_split

X = df_all_data['management_experience_months'].values 
y = df_all_data['monthly_salary'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
X_train
# Out:
# array([15, 49, 94, 38, 93, 46,  7, 56, 19, 67, 71, 65, 73, 29])

# %%
X_test
# Out:
# array([32, 61, 37, 59, 14, 22])

# %%
import pandas as pd
df_training_data = pd.DataFrame({ 'monthly_salary': y_train, 'management_experience_months': X_train})
df_training_data
# Out:
#     monthly_salary  management_experience_months
# 0             1020                            15
# 1             1390                            49
# 2             1590                            94
# 3             1290                            38
# 4             1750                            93
# 5             1240                            46
# 6              960                             7
# 7             1290                            56
# 8              960                            19
# 9             1340                            67
# 10            1480                            71
# 11            1630                            65
# 12            1390                            73
# 13            1170                            29

# %%
# !mkdir -p tmp

# %%
df_training_data.to_csv('tmp/training_data.csv', header=False, index=False)

# %%
s3_bucket = 'sagemaker-cookbook-bucket'
prefix = 'chapter01'

# %%
# !aws s3 cp tmp/training_data.csv s3://{s3_bucket}/{prefix}/input/training_data.csv
# Out:
# upload: tmp/training_data.csv to s3://sagemaker-cookbook-bucket/chapter01/input/training_data.csv

# %%
import sagemaker 
import boto3
from sagemaker import get_execution_role 

role = get_execution_role()
session = sagemaker.Session()
region_name = boto3.Session().region_name

# %%
training_s3_input_location = f"s3://{s3_bucket}/{prefix}/input/training_data.csv" 
training_s3_output_location = f"s3://{s3_bucket}/{prefix}/output/"

# %%
from sagemaker.inputs import TrainingInput

train = TrainingInput(training_s3_input_location, content_type="text/csv")

# %%
train.__dict__
# Out:
# {'config': {'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix',
#     'S3Uri': 's3://sagemaker-cookbook-bucket/chapter01/input/training_data.csv',
#     'S3DataDistributionType': 'FullyReplicated'}},
#   'ContentType': 'text/csv'}}

# %%
from sagemaker.image_uris import retrieve 

container = retrieve("linear-learner", region_name, "1")
container
# Out:
# '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner:1'

# %%
estimator = sagemaker.estimator.Estimator(
    container,
    role, 
    instance_count=1, 
    instance_type='ml.m5.xlarge',
    output_path=training_s3_output_location,
    sagemaker_session=session)

# %%
estimator.set_hyperparameters(predictor_type='regressor', mini_batch_size=4)

# %%
estimator.fit({'train': train})
# Out:
# 2021-03-13 02:23:19 Starting - Starting the training job...
# 2021-03-13 02:23:43 Starting - Launching requested ML instancesProfilerReport-1615602198: InProgress
# .........
# 2021-03-13 02:25:04 Starting - Preparing the instances for training......
# 2021-03-13 02:26:04 Downloading - Downloading input data...
# 2021-03-13 02:26:45 Training - Training image download completed. Training in progress.
# 2021-03-13 02:26:45 Uploading - Uploading generated training modelDocker entrypoint called with argument(s): train
# Running default environment configuration script
# [03/13/2021 02:26:42 INFO 140345420867392] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [03/13/2021 02:26:42 INFO 140345420867392] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'mini_batch_size': u'4', u'predictor_type': u'regressor'}
# [03/13/2021 02:26:42 INFO 140345420867392] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'4', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'regressor', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [03/13/2021 02:26:42 WARNING 140345420867392] Loggers have already been setup.
# Process 1 is a worker.
# [03/13/2021 02:26:42 INFO 140345420867392] Using default worker.
# [03/13/2021 02:26:42 INFO 140345420867392] Checkpoint loading and saving are disabled.
# [03/13/2021 02:26:42 INFO 140345420867392] Create Store: local
# [03/13/2021 02:26:42 INFO 140345420867392] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fa460493fd0>
# [03/13/2021 02:26:42 INFO 140345420867392] Scaling model computed with parameters:
#  {'stdev_weight':
# [27.292654]
# <NDArray 1 @cpu(0)>, 'stdev_label':
# [248.55695]
# <NDArray 1 @cpu(0)>, 'mean_label':
# [1328.3334]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [51.666668]
# <NDArray 1 @cpu(0)>}
# [03/13/2021 02:26:43 INFO 140345420867392] nvidia-smi took: 0.0251529216766 secs to identify 0 gpus
# [03/13/2021 02:26:43 INFO 140345420867392] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 4, "sum": 4.0, "min": 4}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Total Records Seen": {"count": 1, "max": 18, "sum": 18.0, "min": 18}, "Max Records Seen Between Resets": {"count": 1, "max": 14, "sum": 14.0, "min": 14}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1615602403.080709, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1615602403.080672}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.986515740553538, "sum": 0.986515740553538, "min": 0.986515740553538}}, "EndTime": 1615602403.136048, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1615602403.13599}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0297648509343464, "sum": 1.0297648509343464, "min": 1.0297648509343464}}, "EndTime": 1615602403.13612, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1615602403.13611}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9916986227035522, "sum": 0.9916986227035522, "min": 0.9916986227035522}}, "EndTime": 1615602403.136171, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1615602403.136159}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0275290409723918, "sum": 1.0275290409723918, "min": 1.0275290409723918}}, "EndTime": 1615602403.136221, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1615602403.136208}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0600494146347046, "sum": 1.0600494146347046, "min": 1.0600494146347046}}, "EndTime": 1615602403.136265, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1615602403.136254}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0802155335744221, "sum": 1.0802155335744221, "min": 1.0802155335744221}}, "EndTime": 1615602403.136307, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1615602403.136295}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2655052940050762, "sum": 1.2655052940050762, "min": 1.2655052940050762}}, "EndTime": 1615602403.136351, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1615602403.13634}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1983637809753418, "sum": 1.1983637809753418, "min": 1.1983637809753418}}, "EndTime": 1615602403.136392, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1615602403.136382}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.110631783803304, "sum": 1.110631783803304, "min": 1.110631783803304}}, "EndTime": 1615602403.136433, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1615602403.136424}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9608940879503886, "sum": 0.9608940879503886, "min": 0.9608940879503886}}, "EndTime": 1615602403.136477, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1615602403.136466}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9751139283180237, "sum": 0.9751139283180237, "min": 0.9751139283180237}}, "EndTime": 1615602403.136519, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1615602403.136508}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9438297152519226, "sum": 0.9438297152519226, "min": 0.9438297152519226}}, "EndTime": 1615602403.136564, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1615602403.136553}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0783568819363911, "sum": 1.0783568819363911, "min": 1.0783568819363911}}, "EndTime": 1615602403.136608, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1615602403.136597}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1342655817667644, "sum": 1.1342655817667644, "min": 1.1342655817667644}}, "EndTime": 1615602403.136651, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1615602403.13664}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0752590497334797, "sum": 1.0752590497334797, "min": 1.0752590497334797}}, "EndTime": 1615602403.136696, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1615602403.136685}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.148008128007253, "sum": 1.148008128007253, "min": 1.148008128007253}}, "EndTime": 1615602403.136738, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1615602403.136728}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9107179641723633, "sum": 0.9107179641723633, "min": 0.9107179641723633}}, "EndTime": 1615602403.136783, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1615602403.136772}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0193379322687786, "sum": 1.0193379322687786, "min": 1.0193379322687786}}, "EndTime": 1615602403.136829, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1615602403.136817}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9672044515609741, "sum": 0.9672044515609741, "min": 0.9672044515609741}}, "EndTime": 1615602403.136875, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1615602403.
#early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=mse_objective, value=0.129746250808
# [03/13/2021 02:26:43 INFO 140345420867392] Epoch 14: Loss improved. Updating best model
# [03/13/2021 02:26:43 INFO 140345420867392] Saving model for epoch: 14
# [03/13/2021 02:26:43 INFO 140345420867392] Saved checkpoint to "/tmp/tmpcVzQR7/mx-mod-0000.params"
# [03/13/2021 02:26:43 INFO 140345420867392] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 4, "sum": 4.0, "min": 4}, "Number of Batches Since Last Reset": {"count": 1, "max": 4, "sum": 4.0, "min": 4}, "Number of Records Since Last Reset": {"count": 1, "max": 14, "sum": 14.0, "min": 14}, "Total Batches Seen": {"count": 1, "max": 65, "sum": 65.0, "min": 65}, "Total Records Seen": {"count": 1, "max": 228, "sum": 228.0, "min": 228}, "Max Records Seen Between Resets": {"count": 1, "max": 14, "sum": 14.0, "min": 14}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1615602403.992892, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1615602403.940444}
#
# [03/13/2021 02:26:43 INFO 140345420867392] #throughput_metric: host=algo-1, train throughput=266.352125773 records/second
# [03/13/2021 02:26:43 WARNING 140345420867392] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [03/13/2021 02:26:43 WARNING 140345420867392] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [03/13/2021 02:26:44 INFO 140345420867392] #train_score (algo-1) : ('mse_objective', 7907.846958705357)
# [03/13/2021 02:26:44 INFO 140345420867392] #train_score (algo-1) : ('mse', 7907.846958705357)
# [03/13/2021 02:26:44 INFO 140345420867392] #train_score (algo-1) : ('absolute_loss', 72.75599452427456)
# [03/13/2021 02:26:44 INFO 140345420867392] #quality_metric: host=algo-1, train mse_objective <loss>=7907.84695871
# [03/13/2021 02:26:44 INFO 140345420867392] #quality_metric: host=algo-1, train mse <loss>=7907.84695871
# [03/13/2021 02:26:44 INFO 140345420867392] #quality_metric: host=algo-1, train absolute_loss <loss>=72.7559945243
# [03/13/2021 02:26:44 INFO 140345420867392] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 1e-05}
# [03/13/2021 02:26:44 INFO 140345420867392] Saved checkpoint to "/tmp/tmpVqG03V/mx-mod-0000.params"
# [03/13/2021 02:26:44 INFO 140345420867392] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 1240.7071590423584, "sum": 1240.7071590423584, "min": 1240.7071590423584}, "finalize.time": {"count": 1, "max": 12.228012084960938, "sum": 12.228012084960938, "min": 12.228012084960938}, "initialize.time": {"count": 1, "max": 135.6499195098877, "sum": 135.6499195098877, "min": 135.6499195098877}, "check_early_stopping.time": {"count": 15, "max": 0.9019374847412109, "sum": 7.821798324584961, "min": 0.14901161193847656}, "setuptime": {"count": 1, "max": 21.11506462097168, "sum": 21.11506462097168, "min": 21.11506462097168}, "update.time": {"count": 15, "max": 81.72917366027832, "sum": 873.1822967529297, "min": 40.94409942626953}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1615602404.01012, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1615602402.941821}
# 2021-03-13 02:27:05 Completed - Training job completed
# Training seconds: 49
# Billable seconds: 49

# %%
model_data = estimator.model_data
model_data
# Out:
# 's3://sagemaker-cookbook-bucket/chapter01/output/linear-learner-2021-03-13-02-23-18-930/output/model.tar.gz'

# %%
# %store model_data
# Out:
# Stored 'model_data' (str)

# %%
model_uri = estimator.image_uri
model_uri
# Out:
# '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner:1'

# %%
# %store model_uri
# Out:
# Stored 'model_uri' (str)

# %%
# %store X_test
# %store y_test
# Out:
# Stored 'X_test' (ndarray)
# Stored 'y_test' (ndarray)
